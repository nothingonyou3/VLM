# %%
! pip install ftfy regex tqdm
! pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting ftfy
#   Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 875.8 kB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy) (0.2.13)
# Installing collected packages: ftfy
# Successfully installed ftfy-6.2.0
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-vgtsxuvj
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-vgtsxuvj
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (6.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (24.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.66.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.18.0+cu121)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->clip==1.0)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->clip==1.0)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->clip==1.0)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->clip==1.0)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->clip==1.0)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->clip==1.0)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->clip==1.0)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->clip==1.0)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 38.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->clip==1.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->clip==1.0) (1.3.0)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=b3bbdf0f097fdfd1a2dfa227ddbc00d9e6ab7cc79dcce3a89d5a1215faeb4e69
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_cpf3xzc/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, clip
# Successfully installed clip-1.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105

# %%
! pip install open_clip_torch
# Out:
# Collecting open_clip_torch
#   Downloading open_clip_torch-2.24.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from open_clip_torch) (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from open_clip_torch) (0.18.0+cu121)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from open_clip_torch) (2024.5.15)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from open_clip_torch) (6.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from open_clip_torch) (4.66.4)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from open_clip_torch) (0.23.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from open_clip_torch) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from open_clip_torch) (3.20.3)
# Collecting timm (from open_clip_torch)
#   Downloading timm-1.0.3-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->open_clip_torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9.0->open_clip_torch) (12.5.40)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->open_clip_torch) (0.2.13)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->open_clip_torch) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->open_clip_torch) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->open_clip_torch) (2.31.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->open_clip_torch) (0.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->open_clip_torch) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->open_clip_torch) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9.0->open_clip_torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->open_clip_torch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->open_clip_torch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->open_clip_torch) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->open_clip_torch) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9.0->open_clip_torch) (1.3.0)
# Installing collected packages: timm, open_clip_torch
# Successfully installed open_clip_torch-2.24.0 timm-1.0.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import open_clip
import os
import clip
import torch
from PIL import Image

# Load the model
device = "cuda" if torch.cuda.is_available() else "cpu"
#model, preprocess = clip.load('ViT-B/32', device)

model, preprocess_train, preprocess_val = open_clip.create_model_and_transforms('hf-hub:wisdomik/QuiltNet-B-32')
tokenizer = open_clip.get_tokenizer('hf-hub:wisdomik/QuiltNet-B-32')

#Data loading

image_folder = '/content/drive/MyDrive/Unique_BACH_folder'  # Specifica il percorso alla cartella delle immagini
image_files = [f for f in os.listdir(image_folder) if f.endswith(('tif'))]

import pandas as pd

# Leggi il file Excel
df = pd.read_csv('/content/drive/MyDrive/WE/microscopy_ground_truth.csv')

# Inizializza la lista per le coppie
y_vere = []

import numpy as np

y_pred = []

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)


templates = ["a histopathology slide showing {}",
"histopathology image of {}",
"pathology tissue showing {}",
"presence of {} tissue on image"]

classnames = ["Breast normal breast tissue", "Breast non-malignant benign tissue", "Breast malignant in-situ carcinoma", "Breast malignant invasive carcinoma"]

clip_weights = []
for classname in classnames:
    texts = []
    # Tokenize the prompts
    classname = classname.replace('_', ' ')
    for t in templates:
      texts.append(t.format(classname))

    text_tokens = clip.tokenize(texts).to(device)
    class_embeddings = model.encode_text(text_tokens)
    class_embeddings /= class_embeddings.norm(dim=-1, keepdim=True)
    class_embeddings /= class_embeddings.norm(dim=1, keepdim=True)
    clip_weights.append(class_embeddings)
print(len(clip_weights))
clip_weights = torch.stack(clip_weights, dim=-1).to(device)
print(clip_weights.shape)
text_features = clip_weights.mean(dim=0)
print(text_features.shape)

texts = ["Breast normal breast tissue", "Breast non-malignant benign tissue", "Breast malignant in-situ carcinoma", "Breast malignant invasive carcinoma"]
"""
with torch.no_grad():
  text = tokenizer(texts).to(device)
  text_features = model.encode_text(text)
  print(text_features.shape)
  text_features /= text_features.norm(dim=-1, keepdim=True)
  print("THE SHAAAAAAAAAAAAAAAAAAPE---------")
  print(text_features.shape)
"""
y_code = {
    "Normal": 0,
    "Benign": 1,
    "InSitu": 2,
    "Invasive": 3
}

all_pred = []
all_y = []

for index, row in df.iterrows():
    coppia = (row[0], row[1])  # Leggi la colonna 0 e la colonna 1 e crea la coppia
    image_file = row[0]
    yt = row[1]
    y_int = y_code[yt]

    image_path = os.path.join(image_folder, image_file)
    image = Image.open(image_path)

    # Preprocessa l'immagine usando le trasformazioni di validazione
    image_preprocessed = preprocess_val(image).unsqueeze(0)  # aggiungi una dimensione batch
    image_preprocessed = image_preprocessed.to(device)

    with torch.no_grad():
      image_features = model.encode_image(image_preprocessed)
      image_features /= image_features.norm(dim=-1, keepdim=True)

      text_probs = (100.0 * image_features @ text_features).softmax(dim=-1)
      y_hat = text_probs.argmax(dim=-1).item()

    all_pred.append(y_hat)
    all_y.append(y_int)

    acc = ((np.array(all_pred) - np.array(all_y)) == 0).mean() * 100.
    print(f"Accuracy: {acc:.2f}%")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# open_clip_pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# open_clip_config.json:   0%|          | 0.00/469 [00:00<?, ?B/s]
# 4
# torch.Size([4, 512, 4])
# torch.Size([512, 4])
# Accuracy: 100.00%
# Accuracy: 100.00%
# Accuracy: 66.67%
# Accuracy: 50.00%
# Accuracy: 60.00%
# Accuracy: 66.67%
# Accuracy: 71.43%
# Accuracy: 75.00%
# Accuracy: 77.78%
# Accuracy: 80.00%
# Accuracy: 81.82%
# Accuracy: 83.33%
# Accuracy: 84.62%
# Accuracy: 85.71%
# Accuracy: 86.67%
# Accuracy: 87.50%
# Accuracy: 82.35%
# Accuracy: 77.78%
# Accuracy: 78.95%
# Accuracy: 80.00%
# Accuracy: 80.95%
# Accuracy: 81.82%
# Accuracy: 78.26%
# Accuracy: 79.17%
# Accuracy: 80.00%
# Accuracy: 76.92%
# Accuracy: 77.78%
# Accuracy: 78.57%
# Accuracy: 79.31%
# Accuracy: 80.00%
# Accuracy: 80.65%
# Accuracy: 78.12%
# Accuracy: 78.79%
# Accuracy: 76.47%
# Accuracy: 74.29%
# Accuracy: 75.00%
# Accuracy: 75.68%
# Accuracy: 76.32%
# Accuracy: 76.92%
# Accuracy: 77.50%
# Accuracy: 78.05%
# Accuracy: 76.19%
# Accuracy: 76.74%
# Accuracy: 77.27%
# Accuracy: 77.78%
# Accuracy: 78.26%
# Accuracy: 78.72%
# Accuracy: 79.17%
# Accuracy: 79.59%
# Accuracy: 80.00%
# Accuracy: 80.39%
# Accuracy: 80.77%
# Accuracy: 81.13%
# Accuracy: 81.48%
# Accuracy: 81.82%
# Accuracy: 82.14%
# Accuracy: 82.46%
# Accuracy: 81.03%
# Accuracy: 81.36%
# Accuracy: 80.00%
# Accuracy: 80.33%
# Accuracy: 80.65%
# Accuracy: 80.95%
# Accuracy: 81.25%
# Accuracy: 81.54%
# Accuracy: 81.82%
# Accuracy: 82.09%
# Accuracy: 82.35%
# Accuracy: 82.61%
# Accuracy: 82.86%
# Accuracy: 83.10%
# Accuracy: 81.94%
# Accuracy: 82.19%
# Accuracy: 82.43%
# Accuracy: 81.33%
# Accuracy: 81.58%
# Accuracy: 80.52%
# Accuracy: 79.49%
# Accuracy: 78.48%
# Accuracy: 77.50%
# Accuracy: 76.54%
# Accuracy: 75.61%
# Accuracy: 75.90%
# Accuracy: 75.00%
# Accuracy: 75.29%
# Accuracy: 74.42%
# Accuracy: 74.71%
# Accuracy: 75.00%
# Accuracy: 75.28%
# Accuracy: 75.56%
# Accuracy: 74.73%
# Accuracy: 75.00%
# Accuracy: 75.27%
# Accuracy: 75.53%
# Accuracy: 75.79%
# Accuracy: 76.04%
# Accuracy: 76.29%
# Accuracy: 76.53%
# Accuracy: 76.77%
# Accuracy: 77.00%
# Accuracy: 76.24%
# Accuracy: 75.49%
# Accuracy: 74.76%
# Accuracy: 74.04%
# Accuracy: 73.33%
# Accuracy: 72.64%
# Accuracy: 71.96%
# Accuracy: 71.30%
# Accuracy: 70.64%
# Accuracy: 70.00%
# Accuracy: 69.37%
# Accuracy: 68.75%
# Accuracy: 68.14%
# Accuracy: 67.54%
# Accuracy: 66.96%
# Accuracy: 66.38%
# Accuracy: 65.81%
# Accuracy: 65.25%
# Accuracy: 64.71%
# Accuracy: 64.17%
# Accuracy: 63.64%
# Accuracy: 63.11%
# Accuracy: 62.60%
# Accuracy: 62.10%
# Accuracy: 61.60%
# Accuracy: 61.11%
# Accuracy: 60.63%
# Accuracy: 60.16%
# Accuracy: 59.69%
# Accuracy: 59.23%
# Accuracy: 58.78%
# Accuracy: 58.33%
# Accuracy: 57.89%
# Accuracy: 57.46%
# Accuracy: 57.04%
# Accuracy: 56.62%
# Accuracy: 56.20%
# Accuracy: 55.80%
# Accuracy: 55.40%
# Accuracy: 55.00%
# Accuracy: 54.61%
# Accuracy: 54.23%
# Accuracy: 53.85%
# Accuracy: 53.47%
# Accuracy: 53.10%
# Accuracy: 52.74%
# Accuracy: 52.38%
# Accuracy: 52.03%
# Accuracy: 51.68%
# Accuracy: 51.33%
# Accuracy: 50.99%
# Accuracy: 50.66%
# Accuracy: 50.33%
# Accuracy: 50.00%
# Accuracy: 49.68%
# Accuracy: 49.36%
# Accuracy: 49.04%
# Accuracy: 48.73%
# Accuracy: 48.43%
# Accuracy: 48.75%
# Accuracy: 48.45%
# Accuracy: 48.15%
# Accuracy: 47.85%
# Accuracy: 47.56%
# Accuracy: 47.27%
# Accuracy: 46.99%
# Accuracy: 46.71%
# Accuracy: 46.43%
# Accuracy: 46.15%
# Accuracy: 45.88%
# Accuracy: 45.61%
# Accuracy: 45.35%
# Accuracy: 45.09%
# Accuracy: 44.83%
# Accuracy: 44.57%
# Accuracy: 44.32%
# Accuracy: 44.07%
# Accuracy: 43.82%
# Accuracy: 43.58%
# Accuracy: 43.33%
# Accuracy: 43.09%
# Accuracy: 42.86%
# Accuracy: 42.62%
# Accuracy: 42.39%
# Accuracy: 42.16%
# Accuracy: 41.94%
# Accuracy: 41.71%
# Accuracy: 41.49%
# Accuracy: 41.27%
# Accuracy: 41.05%
# Accuracy: 40.84%
# Accuracy: 40.62%
# Accuracy: 40.41%
# Accuracy: 40.21%
# Accuracy: 40.00%
# Accuracy: 39.80%
# Accuracy: 39.59%
# Accuracy: 39.39%
# Accuracy: 39.20%
# Accuracy: 39.00%
# Accuracy: 39.30%
# Accuracy: 39.60%
# Accuracy: 39.90%
# Accuracy: 40.20%
# Accuracy: 40.49%
# Accuracy: 40.78%
# Accuracy: 41.06%
# Accuracy: 40.87%
# Accuracy: 40.67%
# Accuracy: 40.95%
# Accuracy: 41.23%
# Accuracy: 41.51%
# Accuracy: 41.78%
# Accuracy: 42.06%
# Accuracy: 42.33%
# Accuracy: 42.59%
# Accuracy: 42.86%
# Accuracy: 43.12%
# Accuracy: 43.38%
# Accuracy: 43.64%
# Accuracy: 43.89%
# Accuracy: 44.14%
# Accuracy: 44.39%
# Accuracy: 44.64%
# Accuracy: 44.89%
# Accuracy: 45.13%
# Accuracy: 45.37%
# Accuracy: 45.61%
# Accuracy: 45.85%
# Accuracy: 46.09%
# Accuracy: 46.32%
# Accuracy: 46.55%
# Accuracy: 46.35%
# Accuracy: 46.58%
# Accuracy: 46.81%
# Accuracy: 46.61%
# Accuracy: 46.84%
# Accuracy: 47.06%
# Accuracy: 47.28%
# Accuracy: 47.08%
# Accuracy: 47.30%
# Accuracy: 47.11%
# Accuracy: 46.91%
# Accuracy: 47.13%
# Accuracy: 47.35%
# Accuracy: 47.15%
# Accuracy: 47.37%
# Accuracy: 47.58%
# Accuracy: 47.39%
# Accuracy: 47.20%
# Accuracy: 47.41%
# Accuracy: 47.22%
# Accuracy: 47.04%
# Accuracy: 47.24%
# Accuracy: 47.45%
# Accuracy: 47.66%
# Accuracy: 47.47%
# Accuracy: 47.67%
# Accuracy: 47.88%
# Accuracy: 48.08%
# Accuracy: 48.28%
# Accuracy: 48.09%
# Accuracy: 48.29%
# Accuracy: 48.48%
# Accuracy: 48.30%
# Accuracy: 48.50%
# Accuracy: 48.69%
# Accuracy: 48.88%
# Accuracy: 49.07%
# Accuracy: 49.26%
# Accuracy: 49.45%
# Accuracy: 49.63%
# Accuracy: 49.45%
# Accuracy: 49.27%
# Accuracy: 49.45%
# Accuracy: 49.64%
# Accuracy: 49.82%
# Accuracy: 50.00%
# Accuracy: 49.82%
# Accuracy: 50.00%
# Accuracy: 50.18%
# Accuracy: 50.35%
# Accuracy: 50.53%
# Accuracy: 50.70%
# Accuracy: 50.88%
# Accuracy: 51.05%
# Accuracy: 51.22%
# Accuracy: 51.39%
# Accuracy: 51.56%
# Accuracy: 51.72%
# Accuracy: 51.89%
# Accuracy: 51.71%
# Accuracy: 51.88%
# Accuracy: 51.70%
# Accuracy: 51.86%
# Accuracy: 52.03%
# Accuracy: 52.19%
# Accuracy: 52.35%
# Accuracy: 52.17%
# Accuracy: 52.33%
# Accuracy: 52.16%
# Accuracy: 51.99%
# Accuracy: 51.82%
# Accuracy: 51.64%
# Accuracy: 51.48%
# Accuracy: 51.31%
# Accuracy: 51.14%
# Accuracy: 50.97%
# Accuracy: 50.81%
# Accuracy: 50.65%
# Accuracy: 50.48%
# Accuracy: 50.32%
# Accuracy: 50.16%
# Accuracy: 50.00%
# Accuracy: 49.84%
# Accuracy: 50.00%
# Accuracy: 49.84%
# Accuracy: 49.69%
# Accuracy: 49.84%
# Accuracy: 49.69%
# Accuracy: 49.53%
# Accuracy: 49.38%
# Accuracy: 49.23%
# Accuracy: 49.07%
# Accuracy: 49.23%
# Accuracy: 49.39%
# Accuracy: 49.24%
# Accuracy: 49.09%
# Accuracy: 48.94%
# Accuracy: 49.09%
# Accuracy: 48.94%
# Accuracy: 48.80%
# Accuracy: 48.65%
# Accuracy: 48.50%
# Accuracy: 48.36%
# Accuracy: 48.21%
# Accuracy: 48.37%
# Accuracy: 48.22%
# Accuracy: 48.08%
# Accuracy: 47.94%
# Accuracy: 48.09%
# Accuracy: 48.25%
# Accuracy: 48.10%
# Accuracy: 47.97%
# Accuracy: 47.83%
# Accuracy: 47.98%
# Accuracy: 47.84%
# Accuracy: 47.99%
# Accuracy: 47.85%
# Accuracy: 47.71%
# Accuracy: 47.58%
# Accuracy: 47.44%
# Accuracy: 47.31%
# Accuracy: 47.18%
# Accuracy: 47.04%
# Accuracy: 47.19%
# Accuracy: 47.34%
# Accuracy: 47.49%
# Accuracy: 47.35%
# Accuracy: 47.22%
# Accuracy: 47.09%
# Accuracy: 46.96%
# Accuracy: 46.83%
# Accuracy: 46.98%
# Accuracy: 47.12%
# Accuracy: 47.27%
# Accuracy: 47.14%
# Accuracy: 47.01%
# Accuracy: 46.88%
# Accuracy: 46.76%
# Accuracy: 46.63%
# Accuracy: 46.51%
# Accuracy: 46.38%
# Accuracy: 46.26%
# Accuracy: 46.13%
# Accuracy: 46.01%
# Accuracy: 45.89%
# Accuracy: 45.77%
# Accuracy: 45.65%
# Accuracy: 45.53%
# Accuracy: 45.41%
# Accuracy: 45.55%
# Accuracy: 45.43%
# Accuracy: 45.31%
# Accuracy: 45.19%
# Accuracy: 45.08%
# Accuracy: 44.96%
# Accuracy: 44.85%
# Accuracy: 44.73%
# Accuracy: 44.62%
# Accuracy: 44.50%
# Accuracy: 44.64%
# Accuracy: 44.53%
# Accuracy: 44.42%
# Accuracy: 44.30%
# Accuracy: 44.19%
# Accuracy: 44.08%
# Accuracy: 43.97%
# Accuracy: 43.86%
# Accuracy: 43.75%

# %%
# Load the model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load('ViT-B/32', device)

# %%
#New code
# Load the model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load('ViT-B/32', device)

# Download the dataset
cifar100 = CIFAR100(root=os.path.expanduser("~/.cache"), download=True, train=False)

# Prepare the inputs
image, class_id = cifar100[3637]
image_input = preprocess(image).unsqueeze(0).to(device)
text_inputs = torch.cat([clip.tokenize(f"a photo of a {c}") for c in cifar100.classes]).to(device)

# Calculate features
with torch.no_grad():
    image_features = model.encode_image(image_input)
    text_features = model.encode_text(text_inputs)

# Pick the top 5 most similar labels for the image
image_features /= image_features.norm(dim=-1, keepdim=True)
text_features /= text_features.norm(dim=-1, keepdim=True)
similarity = (100.0 * image_features @ text_features.T).softmax(dim=-1)
values, indices = similarity[0].topk(5)

# Print the result
print("\nTop predictions:\n")
for value, index in zip(values, indices):
    print(f"{cifar100.classes[index]:>16s}: {100 * value.item():.2f}%")

# %%
#/QuiltNet-B-32 ALREADY EXECUTED--------------------------------------------------------------
from PIL import Image
import requests
import open_clip

model, preprocess_train, preprocess_val = open_clip.create_model_and_transforms('hf-hub:wisdomik/QuiltNet-B-32') #16
tokenizer = open_clip.get_tokenizer('hf-hub:wisdomik/QuiltNet-B-32')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# open_clip_pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# open_clip_config.json:   0%|          | 0.00/469 [00:00<?, ?B/s]

# %%
import torch
from PIL import Image

# %%
import os
image_folder = '/content/drive/MyDrive/Unique_BACH_folder'  # Specifica il percorso alla cartella delle immagini
image_files = [f for f in os.listdir(image_folder) if f.endswith(('tif'))]

# %%
import pandas as pd

# Leggi il file Excel
df = pd.read_csv('/content/drive/MyDrive/WE/microscopy_ground_truth.csv')


# Inizializza la lista per le coppie
y_vere = []


#-----------------------------------------------------DOVREBBE ESSERCI IL PROBLEMA
# Itera sul DataFrame e crea le coppie
import numpy as np

y_pred = []

# Carica il modello e le trasformazioni
model, preprocess_train, preprocess_val = open_clip.create_model_and_transforms('hf-hub:wisdomik/QuiltNet-B-32')

# Prepara il testo
#corispondenza classe t0, t1, t2, t3
texts = ["Breast normal breast tissue", "Breast non-malignant benign tissue", "Breast malignant in-situ carcinoma", "Breast malignant invasive carcinoma"]
#texts = ["Normal breast tissue histology shows well-organized lobules and ducts lined by a double layer of epithelial and myoepithelial cells. The stroma is composed of dense fibrous connective tissue interspersed with adipose tissue. The epithelial cells are uniform in appearance with no signs of atypia or mitotic activity. Myoepithelial cells are present at the periphery of the ducts and lobules, demonstrating the normal architecture. No inflammatory cells or pathological changes are observed. The tissue exhibits a normal distribution of glandular and stromal components, indicative of healthy breast tissue.","benign","in-situ", "invasive"]

tokenizer = open_clip.get_tokenizer('hf-hub:wisdomik/QuiltNet-B-32')


for index, row in df.iterrows():
    coppia = (row[0], row[1])  # Leggi la colonna 0 e la colonna 1 e crea la coppia
    image_file = row[0]
    yt = row[1]
    image_path = os.path.join(image_folder, image_file)
    image = Image.open(image_path)

    # Preprocessa l'immagine usando le trasformazioni di validazione
    image_preprocessed = preprocess_val(image).unsqueeze(0)  # aggiungi una dimensione batch

    # Tokenizza il testo e calcola la lunghezza massima dei token per ogni batch di testi
    tokenized_texts = [tokenizer.encode(text) for text in texts]
    max_len = max(len(tokens) for tokens in tokenized_texts)

    # Padding dinamico dei testi per ogni batch
    padded_texts = [torch.nn.functional.pad(torch.tensor(tokens), (0, max_len - len(tokens)), 'constant', 0) for tokens in tokenized_texts]
    text_inputs = torch.stack(padded_texts)

    # Sposta il modello e gli input su GPU se disponibile
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    image_preprocessed = image_preprocessed.to(device)
    text_inputs = text_inputs.to(device)

    # Passa gli input preprocessati al modello
    with torch.no_grad():
        image_features = model.encode_image(image_preprocessed)

        # Truncate or pad the text inputs to match the expected length of positional embeddings
        expected_length = model.positional_embedding.shape[0] # Get the expected length from the model
        text_inputs = torch.nn.functional.pad(text_inputs, (0, expected_length - text_inputs.shape[1]), 'constant', 0)  # Pad if shorter
        text_inputs = text_inputs[:, :expected_length]  # Truncate if longer

        text_features = model.encode_text(text_inputs)

    # Calcola le similarità tra immagine e testi
    logits_per_image = (image_features @ text_features.T).softmax(dim=-1) #----------------------

    max_value, max_index = torch.max(logits_per_image, dim=1)
    posizione = "" #valore di supporto per fare cose


    if (max_index.item() == 3):
      posizione = "Invasive"
    elif (max_index.item() == 2):
      posizione = "InSitu"
    elif (max_index.item() == 1):
      posizione = "Benign"
    else:
      posizione = "Normal"


    #Aggiungere gli elementi ad una lista con soli nomi + labels predette
    y_pred.append((yt, posizione))
    print(y_pred[-1])
# Out:
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'InSitu')
# ('Normal', 'Invasive')
# ('Normal', 'InSitu')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'InSitu')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'InSitu')
# ('Normal', 'Invasive')
# ('Normal', 'Normal')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Benign')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'InSitu')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'InSitu')
# ('Normal', 'InSitu')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'InSitu')
# ('Normal', 'InSitu')
# ('Normal', 'InSitu')
# ('Normal', 'InSitu')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'InSitu')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Normal', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Benign')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'InSitu')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Benign')
# ('Benign', 'Invasive')
# ('Benign', 'Benign')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'InSitu')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Benign')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'InSitu')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'InSitu')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Normal')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('Benign', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'InSitu')
# ('InSitu', 'InSitu')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'InSitu')
# ('InSitu', 'InSitu')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'InSitu')
# ('InSitu', 'InSitu')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'InSitu')
# ('InSitu', 'Invasive')
# ('InSitu', 'Invasive')
# ('InSitu', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'Invasive')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'InSitu')
# ('Invasive', 'Invasive')

# %%
label = []
labelp = []
for (y,yp) in y_pred:
  if y== "Invasive":
      label.append(0)
  elif y== "InSitu":
      label.append(1)
  elif y== "Benign":
      label.append(2)
  else:
      label.append(3)
  if yp== "Invasive":
      labelp.append(0)
  elif yp== "InSitu":
      labelp.append(1)
  elif yp== "Benign":
      labelp.append(2)
  else:
      labelp.append(3)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(label, labelp))
# Out:
# [[63 37  0  0]
#  [92  8  0  0]
#  [91  4  4  1]
#  [86 12  1  1]]

# %%
from sklearn.metrics import balanced_accuracy_score
print(balanced_accuracy_score(label, labelp))
# Out:
# 0.19

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(label, labelp))
# Out:
# [[39 58  0  3]
#  [49 46  3  2]
#  [41 28  9 22]
#  [39 36 17  8]]

# %%
from sklearn.metrics import balanced_accuracy_score
print(balanced_accuracy_score(label, labelp))
# Out:
# 0.255

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(label, labelp))
# Out:
# [[20 76  0  4]
#  [19 77  1  3]
#  [13 77  5  5]
#  [ 4 90  3  3]]

# %%
from sklearn.metrics import balanced_accuracy_score
print(balanced_accuracy_score(label, labelp))
# Out:
# 0.2625

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(label, labelp))
# Out:
# [[ 0 97  3  0]
#  [ 0 97  0  3]
#  [ 0 90  3  7]
#  [ 0 93  1  6]]

# %%
from sklearn.metrics import balanced_accuracy_score
print(balanced_accuracy_score(label, labelp))
# Out:
# 0.265

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(label, labelp))
# Out:
# [[63 37  0  0]
#  [92  8  0  0]
#  [91  4  4  1]
#  [86 12  1  1]]

# %%
import numpy as np

y_pred = []

# Carica il modello e le trasformazioni
model, preprocess_train, preprocess_val = open_clip.create_model_and_transforms('hf-hub:wisdomik/QuiltNet-B-32')

# Prepara il testo
#corispondenza classe t0, t1, t2, t3

texts = ["Breast normal breast tissue","Breast non-malignant benign tissue","Breast malignant in-situ carcinoma", "Breast malignant invasive carcinoma",]
tokenizer = open_clip.get_tokenizer('hf-hub:wisdomik/QuiltNet-B-32')

# Itera su ogni immagine nel folder
for image_file in image_files:
    image_path = os.path.join(image_folder, image_file)
    image = Image.open(image_path)

    # Preprocessa l'immagine usando le trasformazioni di validazione
    image_preprocessed = preprocess_val(image).unsqueeze(0)  # aggiungi una dimensione batch

    # Tokenizza il testo e calcola la lunghezza massima dei token per ogni batch di testi
    tokenized_texts = [tokenizer.encode(text) for text in texts]
    max_len = max(len(tokens) for tokens in tokenized_texts)

    # Padding dinamico dei testi per ogni batch
    padded_texts = [torch.nn.functional.pad(torch.tensor(tokens), (0, max_len - len(tokens)), 'constant', 0) for tokens in tokenized_texts]
    text_inputs = torch.stack(padded_texts)

    # Sposta il modello e gli input su GPU se disponibile
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    image_preprocessed = image_preprocessed.to(device)
    text_inputs = text_inputs.to(device)

    # Passa gli input preprocessati al modello
    with torch.no_grad():
        image_features = model.encode_image(image_preprocessed)

        # Truncate or pad the text inputs to match the expected length of positional embeddings
        expected_length = model.positional_embedding.shape[0] # Get the expected length from the model
        text_inputs = torch.nn.functional.pad(text_inputs, (0, expected_length - text_inputs.shape[1]), 'constant', 0)  # Pad if shorter
        text_inputs = text_inputs[:, :expected_length]  # Truncate if longer

        text_features = model.encode_text(text_inputs)

    # Calcola le similarità tra immagine e testi
    logits_per_image = (image_features @ text_features.T).softmax(dim=-1) #----------------------

    max_value, max_index = torch.max(logits_per_image, dim=1)
    posizione = "" #valore di supporto per fare cose


    if (max_index.item() == 3):
      posizione = "Invasive"
    elif (max_index.item() == 2):
      posizione = "InSitu"
    elif (max_index.item() == 1):
      posizione = "Benign"
    else:
      posizione = "Normal"


    #Aggiungere gli elementi ad una lista con soli nomi + labels predette
    y_pred.append((image_file, posizione))






    #Stampa i risultati
    #print(f"Logits per immagine {image_file}:" )
    #print(f"Il valore massimo è {max_value.item()} e si trova in posizione {max_index.item()}")
    #print("\n")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-37f292270b57> in <cell line: 15>()
#      36     # Passa gli input preprocessati al modello
#      37     with torch.no_grad():
# ---> 38         image_features = model.encode_image(image_preprocessed)
#      39
#      40         # Truncate or pad the text inputs to match the expected length of positional embeddings
#
# /usr/local/lib/python3.10/dist-packages/open_clip/model.py in encode_image(self, image, normalize)
#     264
#     265     def encode_image(self, image, normalize: bool = False):
# --> 266         features = self.visual(image)
#     267         return F.normalize(features, dim=-1) if normalize else features
#     268
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/open_clip/transformer.py in forward(self, x)
#     514
#     515         x = x.permute(1, 0, 2)  # NLD -> LND
# --> 516         x = self.transformer(x)
#     517         x = x.permute(1, 0, 2)  # LND -> NLD
#     518
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/open_clip/transformer.py in forward(self, x, attn_mask)
#     322                 x = checkpoint(r, x, None, None, attn_mask)
#     323             else:
# --> 324                 x = r(x, attn_mask=attn_mask)
#     325         return x
#     326
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/open_clip/transformer.py in forward(self, q_x, k_x, v_x, attn_mask)
#     239         v_x = self.ln_1_kv(v_x) if hasattr(self, "ln_1_kv") and v_x is not None else None
#     240
# --> 241         x = q_x + self.ls_1(self.attention(q_x=self.ln_1(q_x), k_x=k_x, v_x=v_x, attn_mask=attn_mask))
#     242         x = x + self.ls_2(self.mlp(self.ln_2(x)))
#     243         return x
#
# /usr/local/lib/python3.10/dist-packages/open_clip/transformer.py in attention(self, q_x, k_x, v_x, attn_mask)
#     225
#     226         attn_mask = attn_mask.to(q_x.dtype) if attn_mask is not None else None
# --> 227         return self.attn(
#     228             q_x, k_x, v_x, need_weights=False, attn_mask=attn_mask
#     229         )[0]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py in forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1264                 is_causal=is_causal)
#    1265         else:
# -> 1266             attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1267                 query, key, value, self.embed_dim, self.num_heads,
#    1268                 self.in_proj_weight, self.in_proj_bias,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v, average_attn_weights, is_causal)
#    5362     if not use_separate_proj_weight:
#    5363         assert in_proj_weight is not None, "use_separate_proj_weight is False but in_proj_weight is None"
# -> 5364         q, k, v = _in_projection_packed(query, key, value, in_proj_weight, in_proj_bias)
#    5365     else:
#    5366         assert q_proj_weight is not None, "use_separate_proj_weight is True but q_proj_weight is None"
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in _in_projection_packed(q, k, v, w, b)
#    4882         if q is k:
#    4883             # self-attention
# -> 4884             proj = linear(q, w, b)
#    4885             # reshape to 3, E and not E, 3 is deliberate for better memory coalescing and keeping same order as chunk()
#    4886             proj = proj.unflatten(-1, (3, E)).unsqueeze(0).transpose(0, -2).squeeze(-2).contiguous()
#
# KeyboardInterrupt:

# %%
#Ora stampo il mio vettore di labels prodotteeeeeeeeeeeeee
print("Valori PREDETTI ----------------------------------------------------------------")

for coppia in y_pred:
  if coppia[0] ==  "n001.tif":
    print("Ci sono")
  else:
    print(coppia)
    print("\n")

print("La lunghezza della lista PRED è:", len(y_pred)) #400 IL MISTERO SI INFITTISCE
# Out:
# Valori PREDETTI ----------------------------------------------------------------
# ('is013.tif', 'Invasive')
#
#
# ('is007.tif', 'Invasive')
#
#
# ('is004.tif', 'Invasive')
#
#
# ('is010.tif', 'Invasive')
#
#
# ('is011.tif', 'Invasive')
#
#
# ('is005.tif', 'Invasive')
#
#
# ('is039.tif', 'InSitu')
#
#
# ('is015.tif', 'Invasive')
#
#
# ('is014.tif', 'Invasive')
#
#
# ('is016.tif', 'Invasive')
#
#
# ('is002.tif', 'Invasive')
#
#
# ('is058.tif', 'Invasive')
#
#
# ('is064.tif', 'Invasive')
#
#
# ('is065.tif', 'Invasive')
#
#
# ('is071.tif', 'Invasive')
#
#
# ('is067.tif', 'Invasive')
#
#
# ('is099.tif', 'Invasive')
#
#
# ('is066.tif', 'Invasive')
#
#
# ('is062.tif', 'InSitu')
#
#
# ('is063.tif', 'Invasive')
#
#
# ('is075.tif', 'InSitu')
#
#
# ('is061.tif', 'InSitu')
#
#
# ('is049.tif', 'Invasive')
#
#
# ('is074.tif', 'Invasive')
#
#
# ('is079.tif', 'Invasive')
#
#
# ('is100.tif', 'InSitu')
#
#
# ('is051.tif', 'Invasive')
#
#
# ('is087.tif', 'Invasive')
#
#
# ('is050.tif', 'Invasive')
#
#
# ('is046.tif', 'Invasive')
#
#
# ('is052.tif', 'Invasive')
#
#
# ('is085.tif', 'Invasive')
#
#
# ('is091.tif', 'Invasive')
#
#
# ('is043.tif', 'Invasive')
#
#
# ('is080.tif', 'Invasive')
#
#
# ('is081.tif', 'Invasive')
#
#
# ('is095.tif', 'Invasive')
#
#
# ('is054.tif', 'Invasive')
#
#
# ('is042.tif', 'Invasive')
#
#
# ('is040.tif', 'Invasive')
#
#
# ('is083.tif', 'Invasive')
#
#
# ('is082.tif', 'Invasive')
#
#
# ('is097.tif', 'InSitu')
#
#
# ('is032.tif', 'Invasive')
#
#
# ('is033.tif', 'Invasive')
#
#
# ('is025.tif', 'Invasive')
#
#
# ('is019.tif', 'Invasive')
#
#
# ('is030.tif', 'Invasive')
#
#
# ('is018.tif', 'Invasive')
#
#
# ('is024.tif', 'Invasive')
#
#
# ('is020.tif', 'Invasive')
#
#
# ('is034.tif', 'Invasive')
#
#
# ('is008.tif', 'Invasive')
#
#
# ('is009.tif', 'Invasive')
#
#
# ('is037.tif', 'Invasive')
#
#
# ('is022.tif', 'Invasive')
#
#
# ('iv023.tif', 'Invasive')
#
#
# ('iv037.tif', 'Invasive')
#
#
# ('iv034.tif', 'Invasive')
#
#
# ('iv035.tif', 'Invasive')
#
#
# ('iv019.tif', 'Invasive')
#
#
# ('iv031.tif', 'Invasive')
#
#
# ('iv024.tif', 'Invasive')
#
#
# ('iv030.tif', 'Invasive')
#
#
# ('iv018.tif', 'Invasive')
#
#
# ('iv032.tif', 'InSitu')
#
#
# ('iv040.tif', 'InSitu')
#
#
# ('iv068.tif', 'InSitu')
#
#
# ('iv054.tif', 'Invasive')
#
#
# ('iv083.tif', 'Invasive')
#
#
# ('iv097.tif', 'InSitu')
#
#
# ('iv069.tif', 'InSitu')
#
#
# ('iv055.tif', 'InSitu')
#
#
# ('iv057.tif', 'Invasive')
#
#
# ('iv041.tif', 'Invasive')
#
#
# ('iv043.tif', 'Invasive')
#
#
# ('iv094.tif', 'Invasive')
#
#
# ('iv080.tif', 'Invasive')
#
#
# ('iv095.tif', 'Invasive')
#
#
# ('iv052.tif', 'Invasive')
#
#
# ('iv056.tif', 'Invasive')
#
#
# ('iv091.tif', 'Invasive')
#
#
# ('iv046.tif', 'Invasive')
#
#
# ('iv085.tif', 'InSitu')
#
#
# ('iv047.tif', 'Invasive')
#
#
# ('iv053.tif', 'InSitu')
#
#
# ('iv086.tif', 'InSitu')
#
#
# ('iv092.tif', 'Invasive')
#
#
# ('iv093.tif', 'Invasive')
#
#
# ('iv078.tif', 'Invasive')
#
#
# ('iv050.tif', 'Invasive')
#
#
# ('iv061.tif', 'InSitu')
#
#
# ('iv049.tif', 'Invasive')
#
#
# ('iv074.tif', 'InSitu')
#
#
# ('iv048.tif', 'Invasive')
#
#
# ('iv060.tif', 'InSitu')
#
#
# ('iv062.tif', 'InSitu')
#
#
# ('iv067.tif', 'Invasive')
#
#
# ('iv073.tif', 'Invasive')
#
#
# ('iv099.tif', 'InSitu')
#
#
# ('iv098.tif', 'InSitu')
#
#
# ('iv072.tif', 'Invasive')
#
#
# ('iv066.tif', 'Invasive')
#
#
# ('iv064.tif', 'Invasive')
#
#
# ('iv071.tif', 'Invasive')
#
#
# ('iv065.tif', 'InSitu')
#
#
# ('iv002.tif', 'InSitu')
#
#
# ('iv017.tif', 'Invasive')
#
#
# ('iv015.tif', 'Invasive')
#
#
# ('iv038.tif', 'InSitu')
#
#
# ('iv010.tif', 'InSitu')
#
#
# ('iv004.tif', 'InSitu')
#
#
# ('iv011.tif', 'InSitu')
#
#
# ('iv013.tif', 'Invasive')
#
#
# ('iv007.tif', 'InSitu')
#
#
# ('iv039.tif', 'InSitu')
#
#
# ('iv012.tif', 'Invasive')
#
#
# ('iv006.tif', 'InSitu')
#
#
# ('b002.tif', 'Invasive')
#
#
# ('b016.tif', 'Invasive')
#
#
# ('b028.tif', 'Invasive')
#
#
# ('b014.tif', 'Invasive')
#
#
# ('b029.tif', 'Invasive')
#
#
# ('b011.tif', 'Benign')
#
#
# ('b039.tif', 'Invasive')
#
#
# ('b004.tif', 'Invasive')
#
#
# ('b010.tif', 'Invasive')
#
#
# ('b006.tif', 'Invasive')
#
#
# ('b012.tif', 'Invasive')
#
#
# ('b007.tif', 'Invasive')
#
#
# ('b060.tif', 'Invasive')
#
#
# ('b048.tif', 'Invasive')
#
#
# ('b075.tif', 'Invasive')
#
#
# ('b049.tif', 'Invasive')
#
#
# ('b063.tif', 'InSitu')
#
#
# ('b062.tif', 'Invasive')
#
#
# ('b089.tif', 'Invasive')
#
#
# ('b099.tif', 'Invasive')
#
#
# ('b072.tif', 'Invasive')
#
#
# ('b066.tif', 'Invasive')
#
#
# ('b073.tif', 'Invasive')
#
#
# ('b065.tif', 'Invasive')
#
#
# ('b071.tif', 'Invasive')
#
#
# ('b059.tif', 'Invasive')
#
#
# ('b070.tif', 'Invasive')
#
#
# ('b058.tif', 'Invasive')
#
#
# ('b082.tif', 'Invasive')
#
#
# ('b069.tif', 'Invasive')
#
#
# ('b055.tif', 'Invasive')
#
#
# ('b054.tif', 'Benign')
#
#
# ('b068.tif', 'Invasive')
#
#
# ('b095.tif', 'Invasive')
#
#
# ('b056.tif', 'Invasive')
#
#
# ('b043.tif', 'Invasive')
#
#
# ('b080.tif', 'Invasive')
#
#
# ('b094.tif', 'Invasive')
#
#
# ('b084.tif', 'Invasive')
#
#
# ('b090.tif', 'Invasive')
#
#
# ('b046.tif', 'Invasive')
#
#
# ('b052.tif', 'Invasive')
#
#
# ('b091.tif', 'Invasive')
#
#
# ('b085.tif', 'Invasive')
#
#
# ('b050.tif', 'Invasive')
#
#
# ('b079.tif', 'Invasive')
#
#
# ('b045.tif', 'Invasive')
#
#
# ('b092.tif', 'Normal')
#
#
# ('b036.tif', 'InSitu')
#
#
# ('b023.tif', 'Invasive')
#
#
# ('b009.tif', 'Invasive')
#
#
# ('b035.tif', 'Invasive')
#
#
# ('b020.tif', 'Invasive')
#
#
# ('b021.tif', 'Invasive')
#
#
# ('b030.tif', 'Invasive')
#
#
# ('b008.tif', 'Invasive')
#
#
# ('b024.tif', 'Invasive')
#
#
# ('b019.tif', 'Invasive')
#
#
# ('b031.tif', 'Benign')
#
#
# ('b032.tif', 'Invasive')
#
#
# ('b033.tif', 'Benign')
#
#
# ('b026.tif', 'InSitu')
#
#
# ('n017.tif', 'Invasive')
#
#
# ('n003.tif', 'Invasive')
#
#
# ('n002.tif', 'Invasive')
#
#
# ('n016.tif', 'Invasive')
#
#
# ('n015.tif', 'Invasive')
#
#
# Ci sono
# ('n029.tif', 'Invasive')
#
#
# ('n010.tif', 'Invasive')
#
#
# ('n004.tif', 'Invasive')
#
#
# ('n038.tif', 'InSitu')
#
#
# ('n007.tif', 'InSitu')
#
#
# ('n013.tif', 'Invasive')
#
#
# ('n100.tif', 'Invasive')
#
#
# ('n088.tif', 'InSitu')
#
#
# ('n062.tif', 'Invasive')
#
#
# ('n073.tif', 'Invasive')
#
#
# ('n098.tif', 'Invasive')
#
#
# ('n065.tif', 'Invasive')
#
#
# ('n071.tif', 'Invasive')
#
#
# ('n070.tif', 'Invasive')
#
#
# ('n064.tif', 'Invasive')
#
#
# ('n082.tif', 'InSitu')
#
#
# ('n055.tif', 'Invasive')
#
#
# ('n041.tif', 'Invasive')
#
#
# ('n069.tif', 'Invasive')
#
#
# ('n068.tif', 'Invasive')
#
#
# ('n054.tif', 'Benign')
#
#
# ('n097.tif', 'Invasive')
#
#
# ('n095.tif', 'Invasive')
#
#
# ('n081.tif', 'Invasive')
#
#
# ('n042.tif', 'Invasive')
#
#
# ('n056.tif', 'Invasive')
#
#
# ('n057.tif', 'Invasive')
#
#
# ('n043.tif', 'Invasive')
#
#
# ('n094.tif', 'Invasive')
#
#
# ('n080.tif', 'Invasive')
#
#
# ('n084.tif', 'Invasive')
#
#
# ('n047.tif', 'InSitu')
#
#
# ('n090.tif', 'InSitu')
#
#
# ('n053.tif', 'Invasive')
#
#
# ('n052.tif', 'Invasive')
#
#
# ('n046.tif', 'Invasive')
#
#
# ('n091.tif', 'Invasive')
#
#
# ('n093.tif', 'InSitu')
#
#
# ('n087.tif', 'InSitu')
#
#
# ('n078.tif', 'Invasive')
#
#
# ('n050.tif', 'Invasive')
#
#
# ('n045.tif', 'Invasive')
#
#
# ('n051.tif', 'Invasive')
#
#
# ('n023.tif', 'Invasive')
#
#
# ('n024.tif', 'Invasive')
#
#
# ('n019.tif', 'Invasive')
#
#
# ('n025.tif', 'Invasive')
#
#
# ('n033.tif', 'Invasive')
#
#
# ('n026.tif', 'Invasive')
#
#
# ('n032.tif', 'Invasive')
#
#
# ('b051.tif', 'Invasive')
#
#
# ('b053.tif', 'Invasive')
#
#
# ('b057.tif', 'Invasive')
#
#
# ('b001.tif', 'Invasive')
#
#
# ('b003.tif', 'Invasive')
#
#
# ('b005.tif', 'Invasive')
#
#
# ('b013.tif', 'Invasive')
#
#
# ('b015.tif', 'Invasive')
#
#
# ('b017.tif', 'Invasive')
#
#
# ('b018.tif', 'Invasive')
#
#
# ('b022.tif', 'Invasive')
#
#
# ('b025.tif', 'Invasive')
#
#
# ('b027.tif', 'Invasive')
#
#
# ('b034.tif', 'Invasive')
#
#
# ('b037.tif', 'Invasive')
#
#
# ('b038.tif', 'Invasive')
#
#
# ('b040.tif', 'Invasive')
#
#
# ('b041.tif', 'Invasive')
#
#
# ('b042.tif', 'Invasive')
#
#
# ('b044.tif', 'Invasive')
#
#
# ('b047.tif', 'Invasive')
#
#
# ('b061.tif', 'Invasive')
#
#
# ('b064.tif', 'Invasive')
#
#
# ('b067.tif', 'Invasive')
#
#
# ('b074.tif', 'Invasive')
#
#
# ('b076.tif', 'Invasive')
#
#
# ('b077.tif', 'Invasive')
#
#
# ('b078.tif', 'Invasive')
#
#
# ('b081.tif', 'Invasive')
#
#
# ('b083.tif', 'Invasive')
#
#
# ('b086.tif', 'InSitu')
#
#
# ('b087.tif', 'Invasive')
#
#
# ('b088.tif', 'Invasive')
#
#
# ('b093.tif', 'Invasive')
#
#
# ('b096.tif', 'Invasive')
#
#
# ('b097.tif', 'Invasive')
#
#
# ('b098.tif', 'Invasive')
#
#
# ('b100.tif', 'Invasive')
#
#
# ('is001.tif', 'Invasive')
#
#
# ('is003.tif', 'Invasive')
#
#
# ('is006.tif', 'Invasive')
#
#
# ('is012.tif', 'Invasive')
#
#
# ('is017.tif', 'Invasive')
#
#
# ('is021.tif', 'Invasive')
#
#
# ('is023.tif', 'Invasive')
#
#
# ('is026.tif', 'Invasive')
#
#
# ('is027.tif', 'Invasive')
#
#
# ('is028.tif', 'Invasive')
#
#
# ('is029.tif', 'Invasive')
#
#
# ('is031.tif', 'Invasive')
#
#
# ('is035.tif', 'Invasive')
#
#
# ('is036.tif', 'Invasive')
#
#
# ('is038.tif', 'InSitu')
#
#
# ('is041.tif', 'Invasive')
#
#
# ('is044.tif', 'Invasive')
#
#
# ('is045.tif', 'Invasive')
#
#
# ('is047.tif', 'Invasive')
#
#
# ('is048.tif', 'Invasive')
#
#
# ('is053.tif', 'Invasive')
#
#
# ('is055.tif', 'Invasive')
#
#
# ('is056.tif', 'Invasive')
#
#
# ('is057.tif', 'Invasive')
#
#
# ('is059.tif', 'Invasive')
#
#
# ('is060.tif', 'Invasive')
#
#
# ('is068.tif', 'Invasive')
#
#
# ('is069.tif', 'Invasive')
#
#
# ('is070.tif', 'Invasive')
#
#
# ('is072.tif', 'Invasive')
#
#
# ('is073.tif', 'Invasive')
#
#
# ('is076.tif', 'InSitu')
#
#
# ('is077.tif', 'Invasive')
#
#
# ('is078.tif', 'Invasive')
#
#
# ('is084.tif', 'Invasive')
#
#
# ('is086.tif', 'Invasive')
#
#
# ('is088.tif', 'Invasive')
#
#
# ('is089.tif', 'Invasive')
#
#
# ('is090.tif', 'Invasive')
#
#
# ('is092.tif', 'Invasive')
#
#
# ('is093.tif', 'Invasive')
#
#
# ('is094.tif', 'Invasive')
#
#
# ('is096.tif', 'Invasive')
#
#
# ('is098.tif', 'Invasive')
#
#
# ('iv001.tif', 'Invasive')
#
#
# ('iv003.tif', 'InSitu')
#
#
# ('iv005.tif', 'InSitu')
#
#
# ('iv008.tif', 'InSitu')
#
#
# ('iv009.tif', 'InSitu')
#
#
# ('iv014.tif', 'Invasive')
#
#
# ('iv016.tif', 'Invasive')
#
#
# ('iv020.tif', 'Invasive')
#
#
# ('iv021.tif', 'Invasive')
#
#
# ('iv022.tif', 'Invasive')
#
#
# ('iv025.tif', 'Invasive')
#
#
# ('iv026.tif', 'Invasive')
#
#
# ('iv027.tif', 'Invasive')
#
#
# ('iv028.tif', 'InSitu')
#
#
# ('iv029.tif', 'Invasive')
#
#
# ('iv033.tif', 'InSitu')
#
#
# ('iv036.tif', 'Invasive')
#
#
# ('iv042.tif', 'Invasive')
#
#
# ('iv044.tif', 'Invasive')
#
#
# ('iv045.tif', 'Invasive')
#
#
# ('iv051.tif', 'Invasive')
#
#
# ('iv058.tif', 'Invasive')
#
#
# ('iv059.tif', 'Invasive')
#
#
# ('iv063.tif', 'Invasive')
#
#
# ('iv070.tif', 'InSitu')
#
#
# ('iv075.tif', 'InSitu')
#
#
# ('iv076.tif', 'Invasive')
#
#
# ('iv077.tif', 'InSitu')
#
#
# ('iv079.tif', 'Invasive')
#
#
# ('iv081.tif', 'InSitu')
#
#
# ('iv082.tif', 'Invasive')
#
#
# ('iv084.tif', 'InSitu')
#
#
# ('iv087.tif', 'Invasive')
#
#
# ('iv088.tif', 'Invasive')
#
#
# ('iv089.tif', 'InSitu')
#
#
# ('iv090.tif', 'Invasive')
#
#
# ('iv096.tif', 'InSitu')
#
#
# ('iv100.tif', 'Invasive')
#
#
# ('n005.tif', 'InSitu')
#
#
# ('n006.tif', 'Invasive')
#
#
# ('n008.tif', 'Invasive')
#
#
# ('n009.tif', 'Invasive')
#
#
# ('n011.tif', 'Invasive')
#
#
# ('n012.tif', 'Invasive')
#
#
# ('n014.tif', 'Invasive')
#
#
# ('n018.tif', 'Invasive')
#
#
# ('n020.tif', 'Invasive')
#
#
# ('n021.tif', 'Invasive')
#
#
# ('n022.tif', 'Invasive')
#
#
# ('n027.tif', 'Invasive')
#
#
# ('n028.tif', 'Invasive')
#
#
# ('n030.tif', 'Invasive')
#
#
# ('n031.tif', 'Invasive')
#
#
# ('n034.tif', 'Invasive')
#
#
# ('n035.tif', 'Invasive')
#
#
# ('n036.tif', 'Invasive')
#
#
# ('n037.tif', 'Invasive')
#
#
# ('n039.tif', 'Invasive')
#
#
# ('n040.tif', 'Invasive')
#
#
# ('n044.tif', 'Invasive')
#
#
# ('n048.tif', 'Invasive')
#
#
# ('n049.tif', 'Normal')
#
#
# ('n058.tif', 'Invasive')
#
#
# ('n059.tif', 'Invasive')
#
#
# ('n060.tif', 'InSitu')
#
#
# ('n061.tif', 'Invasive')
#
#
# ('n063.tif', 'Invasive')
#
#
# ('n066.tif', 'Invasive')
#
#
# ('n067.tif', 'Invasive')
#
#
# ('n072.tif', 'Invasive')
#
#
# ('n074.tif', 'Invasive')
#
#
# ('n075.tif', 'Invasive')
#
#
# ('n076.tif', 'Invasive')
#
#
# ('n077.tif', 'Invasive')
#
#
# ('n079.tif', 'Invasive')
#
#
# ('n083.tif', 'InSitu')
#
#
# ('n085.tif', 'Invasive')
#
#
# ('n086.tif', 'Invasive')
#
#
# ('n089.tif', 'InSitu')
#
#
# ('n092.tif', 'Invasive')
#
#
# ('n096.tif', 'Invasive')
#
#
# ('n099.tif', 'Invasive')
#
#
# La lunghezza della lista PRED è: 400

# %% [markdown]
# CODICE CHE LAVORA SULLE LABELS VERE:

# %%
import pandas as pd

# Leggi il file Excel
df = pd.read_csv('/content/drive/MyDrive/WE/microscopy_ground_truth.csv')


# Inizializza la lista per le coppie
y_vere = []


#-----------------------------------------------------DOVREBBE ESSERCI IL PROBLEMA
# Itera sul DataFrame e crea le coppie

for index, row in df.iterrows():
    coppia = (row[0], row[1])  # Leggi la colonna 0 e la colonna 1 e crea la coppia
    y_vere.append(coppia)  # Aggiungi la coppia alla lista

# Stampa la lista di coppie


print("Valori reali ----------------------------------------------------------------")

for coppia in y_vere:
      print(coppia)
      print("\n")




print("La lunghezza della lista VERE è:", len(y_vere)) #400


#CODCIE FIXATOOOOOOOOOOOO
# Out:
# Valori reali ----------------------------------------------------------------
# C'e anche il 001-------------------------------
# ('n002.tif', 'Normal')
#
#
# ('n003.tif', 'Normal')
#
#
# ('n004.tif', 'Normal')
#
#
# ('n005.tif', 'Normal')
#
#
# ('n006.tif', 'Normal')
#
#
# ('n007.tif', 'Normal')
#
#
# ('n008.tif', 'Normal')
#
#
# ('n009.tif', 'Normal')
#
#
# ('n010.tif', 'Normal')
#
#
# ('n011.tif', 'Normal')
#
#
# ('n012.tif', 'Normal')
#
#
# ('n013.tif', 'Normal')
#
#
# ('n014.tif', 'Normal')
#
#
# ('n015.tif', 'Normal')
#
#
# ('n016.tif', 'Normal')
#
#
# ('n017.tif', 'Normal')
#
#
# ('n018.tif', 'Normal')
#
#
# ('n019.tif', 'Normal')
#
#
# ('n020.tif', 'Normal')
#
#
# ('n021.tif', 'Normal')
#
#
# ('n022.tif', 'Normal')
#
#
# ('n023.tif', 'Normal')
#
#
# ('n024.tif', 'Normal')
#
#
# ('n025.tif', 'Normal')
#
#
# ('n026.tif', 'Normal')
#
#
# ('n027.tif', 'Normal')
#
#
# ('n028.tif', 'Normal')
#
#
# ('n029.tif', 'Normal')
#
#
# ('n030.tif', 'Normal')
#
#
# ('n031.tif', 'Normal')
#
#
# ('n032.tif', 'Normal')
#
#
# ('n033.tif', 'Normal')
#
#
# ('n034.tif', 'Normal')
#
#
# ('n035.tif', 'Normal')
#
#
# ('n036.tif', 'Normal')
#
#
# ('n037.tif', 'Normal')
#
#
# ('n038.tif', 'Normal')
#
#
# ('n039.tif', 'Normal')
#
#
# ('n040.tif', 'Normal')
#
#
# ('n041.tif', 'Normal')
#
#
# ('n042.tif', 'Normal')
#
#
# ('n043.tif', 'Normal')
#
#
# ('n044.tif', 'Normal')
#
#
# ('n045.tif', 'Normal')
#
#
# ('n046.tif', 'Normal')
#
#
# ('n047.tif', 'Normal')
#
#
# ('n048.tif', 'Normal')
#
#
# ('n049.tif', 'Normal')
#
#
# ('n050.tif', 'Normal')
#
#
# ('n051.tif', 'Normal')
#
#
# ('n052.tif', 'Normal')
#
#
# ('n053.tif', 'Normal')
#
#
# ('n054.tif', 'Normal')
#
#
# ('n055.tif', 'Normal')
#
#
# ('n056.tif', 'Normal')
#
#
# ('n057.tif', 'Normal')
#
#
# ('n058.tif', 'Normal')
#
#
# ('n059.tif', 'Normal')
#
#
# ('n060.tif', 'Normal')
#
#
# ('n061.tif', 'Normal')
#
#
# ('n062.tif', 'Normal')
#
#
# ('n063.tif', 'Normal')
#
#
# ('n064.tif', 'Normal')
#
#
# ('n065.tif', 'Normal')
#
#
# ('n066.tif', 'Normal')
#
#
# ('n067.tif', 'Normal')
#
#
# ('n068.tif', 'Normal')
#
#
# ('n069.tif', 'Normal')
#
#
# ('n070.tif', 'Normal')
#
#
# ('n071.tif', 'Normal')
#
#
# ('n072.tif', 'Normal')
#
#
# ('n073.tif', 'Normal')
#
#
# ('n074.tif', 'Normal')
#
#
# ('n075.tif', 'Normal')
#
#
# ('n076.tif', 'Normal')
#
#
# ('n077.tif', 'Normal')
#
#
# ('n078.tif', 'Normal')
#
#
# ('n079.tif', 'Normal')
#
#
# ('n080.tif', 'Normal')
#
#
# ('n081.tif', 'Normal')
#
#
# ('n082.tif', 'Normal')
#
#
# ('n083.tif', 'Normal')
#
#
# ('n084.tif', 'Normal')
#
#
# ('n085.tif', 'Normal')
#
#
# ('n086.tif', 'Normal')
#
#
# ('n087.tif', 'Normal')
#
#
# ('n088.tif', 'Normal')
#
#
# ('n089.tif', 'Normal')
#
#
# ('n090.tif', 'Normal')
#
#
# ('n091.tif', 'Normal')
#
#
# ('n092.tif', 'Normal')
#
#
# ('n093.tif', 'Normal')
#
#
# ('n094.tif', 'Normal')
#
#
# ('n095.tif', 'Normal')
#
#
# ('n096.tif', 'Normal')
#
#
# ('n097.tif', 'Normal')
#
#
# ('n098.tif', 'Normal')
#
#
# ('n099.tif', 'Normal')
#
#
# ('n100.tif', 'Normal')
#
#
# ('b001.tif', 'Benign')
#
#
# ('b002.tif', 'Benign')
#
#
# ('b003.tif', 'Benign')
#
#
# ('b004.tif', 'Benign')
#
#
# ('b005.tif', 'Benign')
#
#
# ('b006.tif', 'Benign')
#
#
# ('b007.tif', 'Benign')
#
#
# ('b008.tif', 'Benign')
#
#
# ('b009.tif', 'Benign')
#
#
# ('b010.tif', 'Benign')
#
#
# ('b011.tif', 'Benign')
#
#
# ('b012.tif', 'Benign')
#
#
# ('b013.tif', 'Benign')
#
#
# ('b014.tif', 'Benign')
#
#
# ('b015.tif', 'Benign')
#
#
# ('b016.tif', 'Benign')
#
#
# ('b017.tif', 'Benign')
#
#
# ('b018.tif', 'Benign')
#
#
# ('b019.tif', 'Benign')
#
#
# ('b020.tif', 'Benign')
#
#
# ('b021.tif', 'Benign')
#
#
# ('b022.tif', 'Benign')
#
#
# ('b023.tif', 'Benign')
#
#
# ('b024.tif', 'Benign')
#
#
# ('b025.tif', 'Benign')
#
#
# ('b026.tif', 'Benign')
#
#
# ('b027.tif', 'Benign')
#
#
# ('b028.tif', 'Benign')
#
#
# ('b029.tif', 'Benign')
#
#
# ('b030.tif', 'Benign')
#
#
# ('b031.tif', 'Benign')
#
#
# ('b032.tif', 'Benign')
#
#
# ('b033.tif', 'Benign')
#
#
# ('b034.tif', 'Benign')
#
#
# ('b035.tif', 'Benign')
#
#
# ('b036.tif', 'Benign')
#
#
# ('b037.tif', 'Benign')
#
#
# ('b038.tif', 'Benign')
#
#
# ('b039.tif', 'Benign')
#
#
# ('b040.tif', 'Benign')
#
#
# ('b041.tif', 'Benign')
#
#
# ('b042.tif', 'Benign')
#
#
# ('b043.tif', 'Benign')
#
#
# ('b044.tif', 'Benign')
#
#
# ('b045.tif', 'Benign')
#
#
# ('b046.tif', 'Benign')
#
#
# ('b047.tif', 'Benign')
#
#
# ('b048.tif', 'Benign')
#
#
# ('b049.tif', 'Benign')
#
#
# ('b050.tif', 'Benign')
#
#
# ('b051.tif', 'Benign')
#
#
# ('b052.tif', 'Benign')
#
#
# ('b053.tif', 'Benign')
#
#
# ('b054.tif', 'Benign')
#
#
# ('b055.tif', 'Benign')
#
#
# ('b056.tif', 'Benign')
#
#
# ('b057.tif', 'Benign')
#
#
# ('b058.tif', 'Benign')
#
#
# ('b059.tif', 'Benign')
#
#
# ('b060.tif', 'Benign')
#
#
# ('b061.tif', 'Benign')
#
#
# ('b062.tif', 'Benign')
#
#
# ('b063.tif', 'Benign')
#
#
# ('b064.tif', 'Benign')
#
#
# ('b065.tif', 'Benign')
#
#
# ('b066.tif', 'Benign')
#
#
# ('b067.tif', 'Benign')
#
#
# ('b068.tif', 'Benign')
#
#
# ('b069.tif', 'Benign')
#
#
# ('b070.tif', 'Benign')
#
#
# ('b071.tif', 'Benign')
#
#
# ('b072.tif', 'Benign')
#
#
# ('b073.tif', 'Benign')
#
#
# ('b074.tif', 'Benign')
#
#
# ('b075.tif', 'Benign')
#
#
# ('b076.tif', 'Benign')
#
#
# ('b077.tif', 'Benign')
#
#
# ('b078.tif', 'Benign')
#
#
# ('b079.tif', 'Benign')
#
#
# ('b080.tif', 'Benign')
#
#
# ('b081.tif', 'Benign')
#
#
# ('b082.tif', 'Benign')
#
#
# ('b083.tif', 'Benign')
#
#
# ('b084.tif', 'Benign')
#
#
# ('b085.tif', 'Benign')
#
#
# ('b086.tif', 'Benign')
#
#
# ('b087.tif', 'Benign')
#
#
# ('b088.tif', 'Benign')
#
#
# ('b089.tif', 'Benign')
#
#
# ('b090.tif', 'Benign')
#
#
# ('b091.tif', 'Benign')
#
#
# ('b092.tif', 'Benign')
#
#
# ('b093.tif', 'Benign')
#
#
# ('b094.tif', 'Benign')
#
#
# ('b095.tif', 'Benign')
#
#
# ('b096.tif', 'Benign')
#
#
# ('b097.tif', 'Benign')
#
#
# ('b098.tif', 'Benign')
#
#
# ('b099.tif', 'Benign')
#
#
# ('b100.tif', 'Benign')
#
#
# ('is001.tif', 'InSitu')
#
#
# ('is002.tif', 'InSitu')
#
#
# ('is003.tif', 'InSitu')
#
#
# ('is004.tif', 'InSitu')
#
#
# ('is005.tif', 'InSitu')
#
#
# ('is006.tif', 'InSitu')
#
#
# ('is007.tif', 'InSitu')
#
#
# ('is008.tif', 'InSitu')
#
#
# ('is009.tif', 'InSitu')
#
#
# ('is010.tif', 'InSitu')
#
#
# ('is011.tif', 'InSitu')
#
#
# ('is012.tif', 'InSitu')
#
#
# ('is013.tif', 'InSitu')
#
#
# ('is014.tif', 'InSitu')
#
#
# ('is015.tif', 'InSitu')
#
#
# ('is016.tif', 'InSitu')
#
#
# ('is017.tif', 'InSitu')
#
#
# ('is018.tif', 'InSitu')
#
#
# ('is019.tif', 'InSitu')
#
#
# ('is020.tif', 'InSitu')
#
#
# ('is021.tif', 'InSitu')
#
#
# ('is022.tif', 'InSitu')
#
#
# ('is023.tif', 'InSitu')
#
#
# ('is024.tif', 'InSitu')
#
#
# ('is025.tif', 'InSitu')
#
#
# ('is026.tif', 'InSitu')
#
#
# ('is027.tif', 'InSitu')
#
#
# ('is028.tif', 'InSitu')
#
#
# ('is029.tif', 'InSitu')
#
#
# ('is030.tif', 'InSitu')
#
#
# ('is031.tif', 'InSitu')
#
#
# ('is032.tif', 'InSitu')
#
#
# ('is033.tif', 'InSitu')
#
#
# ('is034.tif', 'InSitu')
#
#
# ('is035.tif', 'InSitu')
#
#
# ('is036.tif', 'InSitu')
#
#
# ('is037.tif', 'InSitu')
#
#
# ('is038.tif', 'InSitu')
#
#
# ('is039.tif', 'InSitu')
#
#
# ('is040.tif', 'InSitu')
#
#
# ('is041.tif', 'InSitu')
#
#
# ('is042.tif', 'InSitu')
#
#
# ('is043.tif', 'InSitu')
#
#
# ('is044.tif', 'InSitu')
#
#
# ('is045.tif', 'InSitu')
#
#
# ('is046.tif', 'InSitu')
#
#
# ('is047.tif', 'InSitu')
#
#
# ('is048.tif', 'InSitu')
#
#
# ('is049.tif', 'InSitu')
#
#
# ('is050.tif', 'InSitu')
#
#
# ('is051.tif', 'InSitu')
#
#
# ('is052.tif', 'InSitu')
#
#
# ('is053.tif', 'InSitu')
#
#
# ('is054.tif', 'InSitu')
#
#
# ('is055.tif', 'InSitu')
#
#
# ('is056.tif', 'InSitu')
#
#
# ('is057.tif', 'InSitu')
#
#
# ('is058.tif', 'InSitu')
#
#
# ('is059.tif', 'InSitu')
#
#
# ('is060.tif', 'InSitu')
#
#
# ('is061.tif', 'InSitu')
#
#
# ('is062.tif', 'InSitu')
#
#
# ('is063.tif', 'InSitu')
#
#
# ('is064.tif', 'InSitu')
#
#
# ('is065.tif', 'InSitu')
#
#
# ('is066.tif', 'InSitu')
#
#
# ('is067.tif', 'InSitu')
#
#
# ('is068.tif', 'InSitu')
#
#
# ('is069.tif', 'InSitu')
#
#
# ('is070.tif', 'InSitu')
#
#
# ('is071.tif', 'InSitu')
#
#
# ('is072.tif', 'InSitu')
#
#
# ('is073.tif', 'InSitu')
#
#
# ('is074.tif', 'InSitu')
#
#
# ('is075.tif', 'InSitu')
#
#
# ('is076.tif', 'InSitu')
#
#
# ('is077.tif', 'InSitu')
#
#
# ('is078.tif', 'InSitu')
#
#
# ('is079.tif', 'InSitu')
#
#
# ('is080.tif', 'InSitu')
#
#
# ('is081.tif', 'InSitu')
#
#
# ('is082.tif', 'InSitu')
#
#
# ('is083.tif', 'InSitu')
#
#
# ('is084.tif', 'InSitu')
#
#
# ('is085.tif', 'InSitu')
#
#
# ('is086.tif', 'InSitu')
#
#
# ('is087.tif', 'InSitu')
#
#
# ('is088.tif', 'InSitu')
#
#
# ('is089.tif', 'InSitu')
#
#
# ('is090.tif', 'InSitu')
#
#
# ('is091.tif', 'InSitu')
#
#
# ('is092.tif', 'InSitu')
#
#
# ('is093.tif', 'InSitu')
#
#
# ('is094.tif', 'InSitu')
#
#
# ('is095.tif', 'InSitu')
#
#
# ('is096.tif', 'InSitu')
#
#
# ('is097.tif', 'InSitu')
#
#
# ('is098.tif', 'InSitu')
#
#
# ('is099.tif', 'InSitu')
#
#
# ('is100.tif', 'InSitu')
#
#
# ('iv001.tif', 'Invasive')
#
#
# ('iv002.tif', 'Invasive')
#
#
# ('iv003.tif', 'Invasive')
#
#
# ('iv004.tif', 'Invasive')
#
#
# ('iv005.tif', 'Invasive')
#
#
# ('iv006.tif', 'Invasive')
#
#
# ('iv007.tif', 'Invasive')
#
#
# ('iv008.tif', 'Invasive')
#
#
# ('iv009.tif', 'Invasive')
#
#
# ('iv010.tif', 'Invasive')
#
#
# ('iv011.tif', 'Invasive')
#
#
# ('iv012.tif', 'Invasive')
#
#
# ('iv013.tif', 'Invasive')
#
#
# ('iv014.tif', 'Invasive')
#
#
# ('iv015.tif', 'Invasive')
#
#
# ('iv016.tif', 'Invasive')
#
#
# ('iv017.tif', 'Invasive')
#
#
# ('iv018.tif', 'Invasive')
#
#
# ('iv019.tif', 'Invasive')
#
#
# ('iv020.tif', 'Invasive')
#
#
# ('iv021.tif', 'Invasive')
#
#
# ('iv022.tif', 'Invasive')
#
#
# ('iv023.tif', 'Invasive')
#
#
# ('iv024.tif', 'Invasive')
#
#
# ('iv025.tif', 'Invasive')
#
#
# ('iv026.tif', 'Invasive')
#
#
# ('iv027.tif', 'Invasive')
#
#
# ('iv028.tif', 'Invasive')
#
#
# ('iv029.tif', 'Invasive')
#
#
# ('iv030.tif', 'Invasive')
#
#
# ('iv031.tif', 'Invasive')
#
#
# ('iv032.tif', 'Invasive')
#
#
# ('iv033.tif', 'Invasive')
#
#
# ('iv034.tif', 'Invasive')
#
#
# ('iv035.tif', 'Invasive')
#
#
# ('iv036.tif', 'Invasive')
#
#
# ('iv037.tif', 'Invasive')
#
#
# ('iv038.tif', 'Invasive')
#
#
# ('iv039.tif', 'Invasive')
#
#
# ('iv040.tif', 'Invasive')
#
#
# ('iv041.tif', 'Invasive')
#
#
# ('iv042.tif', 'Invasive')
#
#
# ('iv043.tif', 'Invasive')
#
#
# ('iv044.tif', 'Invasive')
#
#
# ('iv045.tif', 'Invasive')
#
#
# ('iv046.tif', 'Invasive')
#
#
# ('iv047.tif', 'Invasive')
#
#
# ('iv048.tif', 'Invasive')
#
#
# ('iv049.tif', 'Invasive')
#
#
# ('iv050.tif', 'Invasive')
#
#
# ('iv051.tif', 'Invasive')
#
#
# ('iv052.tif', 'Invasive')
#
#
# ('iv053.tif', 'Invasive')
#
#
# ('iv054.tif', 'Invasive')
#
#
# ('iv055.tif', 'Invasive')
#
#
# ('iv056.tif', 'Invasive')
#
#
# ('iv057.tif', 'Invasive')
#
#
# ('iv058.tif', 'Invasive')
#
#
# ('iv059.tif', 'Invasive')
#
#
# ('iv060.tif', 'Invasive')
#
#
# ('iv061.tif', 'Invasive')
#
#
# ('iv062.tif', 'Invasive')
#
#
# ('iv063.tif', 'Invasive')
#
#
# ('iv064.tif', 'Invasive')
#
#
# ('iv065.tif', 'Invasive')
#
#
# ('iv066.tif', 'Invasive')
#
#
# ('iv067.tif', 'Invasive')
#
#
# ('iv068.tif', 'Invasive')
#
#
# ('iv069.tif', 'Invasive')
#
#
# ('iv070.tif', 'Invasive')
#
#
# ('iv071.tif', 'Invasive')
#
#
# ('iv072.tif', 'Invasive')
#
#
# ('iv073.tif', 'Invasive')
#
#
# ('iv074.tif', 'Invasive')
#
#
# ('iv075.tif', 'Invasive')
#
#
# ('iv076.tif', 'Invasive')
#
#
# ('iv077.tif', 'Invasive')
#
#
# ('iv078.tif', 'Invasive')
#
#
# ('iv079.tif', 'Invasive')
#
#
# ('iv080.tif', 'Invasive')
#
#
# ('iv081.tif', 'Invasive')
#
#
# ('iv082.tif', 'Invasive')
#
#
# ('iv083.tif', 'Invasive')
#
#
# ('iv084.tif', 'Invasive')
#
#
# ('iv085.tif', 'Invasive')
#
#
# ('iv086.tif', 'Invasive')
#
#
# ('iv087.tif', 'Invasive')
#
#
# ('iv088.tif', 'Invasive')
#
#
# ('iv089.tif', 'Invasive')
#
#
# ('iv090.tif', 'Invasive')
#
#
# ('iv091.tif', 'Invasive')
#
#
# ('iv092.tif', 'Invasive')
#
#
# ('iv093.tif', 'Invasive')
#
#
# ('iv094.tif', 'Invasive')
#
#
# ('iv095.tif', 'Invasive')
#
#
# ('iv096.tif', 'Invasive')
#
#
# ('iv097.tif', 'Invasive')
#
#
# ('iv098.tif', 'Invasive')
#
#
# ('iv099.tif', 'Invasive')
#
#
# ('iv100.tif', 'Invasive')
#
#
# La lunghezza della lista VERE è: 400

# %% [markdown]
# Sezione del codice in cui, dopo aver verificato la corretta creazione delle due liste andiamo a calcolare l'accuracyyyyyyyy

# %%
#NON COMPILARE PIUUUUUUUUUUUUU SOLO PER BACKUP DI CODICE

#Andiamo a ripulire il contenuto di y_vere
y_vere = y_vere[:-2]
#verifico la composizione della lista a cui ho inserito l'elemento. Consiglio di fare l'inserimento in una cella separata in maniera tale da aggiungerlo solo quando necessario<
for coppia in y_vere:
    print(coppia)
    print("\n")
#Da qui in poi non modificheremo piu il contenuto di y_vere
# Out:
# ('n002.tif', 'Normal')
#
#
# ('n003.tif', 'Normal')
#
#
# ('n004.tif', 'Normal')
#
#
# ('n005.tif', 'Normal')
#
#
# ('n006.tif', 'Normal')
#
#
# ('n007.tif', 'Normal')
#
#
# ('n008.tif', 'Normal')
#
#
# ('n009.tif', 'Normal')
#
#
# ('n010.tif', 'Normal')
#
#
# ('n011.tif', 'Normal')
#
#
# ('n012.tif', 'Normal')
#
#
# ('n013.tif', 'Normal')
#
#
# ('n014.tif', 'Normal')
#
#
# ('n015.tif', 'Normal')
#
#
# ('n016.tif', 'Normal')
#
#
# ('n017.tif', 'Normal')
#
#
# ('n018.tif', 'Normal')
#
#
# ('n019.tif', 'Normal')
#
#
# ('n020.tif', 'Normal')
#
#
# ('n021.tif', 'Normal')
#
#
# ('n022.tif', 'Normal')
#
#
# ('n023.tif', 'Normal')
#
#
# ('n024.tif', 'Normal')
#
#
# ('n025.tif', 'Normal')
#
#
# ('n026.tif', 'Normal')
#
#
# ('n027.tif', 'Normal')
#
#
# ('n028.tif', 'Normal')
#
#
# ('n029.tif', 'Normal')
#
#
# ('n030.tif', 'Normal')
#
#
# ('n031.tif', 'Normal')
#
#
# ('n032.tif', 'Normal')
#
#
# ('n033.tif', 'Normal')
#
#
# ('n034.tif', 'Normal')
#
#
# ('n035.tif', 'Normal')
#
#
# ('n036.tif', 'Normal')
#
#
# ('n037.tif', 'Normal')
#
#
# ('n038.tif', 'Normal')
#
#
# ('n039.tif', 'Normal')
#
#
# ('n040.tif', 'Normal')
#
#
# ('n041.tif', 'Normal')
#
#
# ('n042.tif', 'Normal')
#
#
# ('n043.tif', 'Normal')
#
#
# ('n044.tif', 'Normal')
#
#
# ('n045.tif', 'Normal')
#
#
# ('n046.tif', 'Normal')
#
#
# ('n047.tif', 'Normal')
#
#
# ('n048.tif', 'Normal')
#
#
# ('n049.tif', 'Normal')
#
#
# ('n050.tif', 'Normal')
#
#
# ('n051.tif', 'Normal')
#
#
# ('n052.tif', 'Normal')
#
#
# ('n053.tif', 'Normal')
#
#
# ('n054.tif', 'Normal')
#
#
# ('n055.tif', 'Normal')
#
#
# ('n056.tif', 'Normal')
#
#
# ('n057.tif', 'Normal')
#
#
# ('n058.tif', 'Normal')
#
#
# ('n059.tif', 'Normal')
#
#
# ('n060.tif', 'Normal')
#
#
# ('n061.tif', 'Normal')
#
#
# ('n062.tif', 'Normal')
#
#
# ('n063.tif', 'Normal')
#
#
# ('n064.tif', 'Normal')
#
#
# ('n065.tif', 'Normal')
#
#
# ('n066.tif', 'Normal')
#
#
# ('n067.tif', 'Normal')
#
#
# ('n068.tif', 'Normal')
#
#
# ('n069.tif', 'Normal')
#
#
# ('n070.tif', 'Normal')
#
#
# ('n071.tif', 'Normal')
#
#
# ('n072.tif', 'Normal')
#
#
# ('n073.tif', 'Normal')
#
#
# ('n074.tif', 'Normal')
#
#
# ('n075.tif', 'Normal')
#
#
# ('n076.tif', 'Normal')
#
#
# ('n077.tif', 'Normal')
#
#
# ('n078.tif', 'Normal')
#
#
# ('n079.tif', 'Normal')
#
#
# ('n080.tif', 'Normal')
#
#
# ('n081.tif', 'Normal')
#
#
# ('n082.tif', 'Normal')
#
#
# ('n083.tif', 'Normal')
#
#
# ('n084.tif', 'Normal')
#
#
# ('n085.tif', 'Normal')
#
#
# ('n086.tif', 'Normal')
#
#
# ('n087.tif', 'Normal')
#
#
# ('n088.tif', 'Normal')
#
#
# ('n089.tif', 'Normal')
#
#
# ('n090.tif', 'Normal')
#
#
# ('n091.tif', 'Normal')
#
#
# ('n092.tif', 'Normal')
#
#
# ('n093.tif', 'Normal')
#
#
# ('n094.tif', 'Normal')
#
#
# ('n095.tif', 'Normal')
#
#
# ('n096.tif', 'Normal')
#
#
# ('n097.tif', 'Normal')
#
#
# ('n098.tif', 'Normal')
#
#
# ('n099.tif', 'Normal')
#
#
# ('n100.tif', 'Normal')
#
#
# ('b001.tif', 'Benign')
#
#
# ('b002.tif', 'Benign')
#
#
# ('b003.tif', 'Benign')
#
#
# ('b004.tif', 'Benign')
#
#
# ('b005.tif', 'Benign')
#
#
# ('b006.tif', 'Benign')
#
#
# ('b007.tif', 'Benign')
#
#
# ('b008.tif', 'Benign')
#
#
# ('b009.tif', 'Benign')
#
#
# ('b010.tif', 'Benign')
#
#
# ('b011.tif', 'Benign')
#
#
# ('b012.tif', 'Benign')
#
#
# ('b013.tif', 'Benign')
#
#
# ('b014.tif', 'Benign')
#
#
# ('b015.tif', 'Benign')
#
#
# ('b016.tif', 'Benign')
#
#
# ('b017.tif', 'Benign')
#
#
# ('b018.tif', 'Benign')
#
#
# ('b019.tif', 'Benign')
#
#
# ('b020.tif', 'Benign')
#
#
# ('b021.tif', 'Benign')
#
#
# ('b022.tif', 'Benign')
#
#
# ('b023.tif', 'Benign')
#
#
# ('b024.tif', 'Benign')
#
#
# ('b025.tif', 'Benign')
#
#
# ('b026.tif', 'Benign')
#
#
# ('b027.tif', 'Benign')
#
#
# ('b028.tif', 'Benign')
#
#
# ('b029.tif', 'Benign')
#
#
# ('b030.tif', 'Benign')
#
#
# ('b031.tif', 'Benign')
#
#
# ('b032.tif', 'Benign')
#
#
# ('b033.tif', 'Benign')
#
#
# ('b034.tif', 'Benign')
#
#
# ('b035.tif', 'Benign')
#
#
# ('b036.tif', 'Benign')
#
#
# ('b037.tif', 'Benign')
#
#
# ('b038.tif', 'Benign')
#
#
# ('b039.tif', 'Benign')
#
#
# ('b040.tif', 'Benign')
#
#
# ('b041.tif', 'Benign')
#
#
# ('b042.tif', 'Benign')
#
#
# ('b043.tif', 'Benign')
#
#
# ('b044.tif', 'Benign')
#
#
# ('b045.tif', 'Benign')
#
#
# ('b046.tif', 'Benign')
#
#
# ('b047.tif', 'Benign')
#
#
# ('b048.tif', 'Benign')
#
#
# ('b049.tif', 'Benign')
#
#
# ('b050.tif', 'Benign')
#
#
# ('b051.tif', 'Benign')
#
#
# ('b052.tif', 'Benign')
#
#
# ('b053.tif', 'Benign')
#
#
# ('b054.tif', 'Benign')
#
#
# ('b055.tif', 'Benign')
#
#
# ('b056.tif', 'Benign')
#
#
# ('b057.tif', 'Benign')
#
#
# ('b058.tif', 'Benign')
#
#
# ('b059.tif', 'Benign')
#
#
# ('b060.tif', 'Benign')
#
#
# ('b061.tif', 'Benign')
#
#
# ('b062.tif', 'Benign')
#
#
# ('b063.tif', 'Benign')
#
#
# ('b064.tif', 'Benign')
#
#
# ('b065.tif', 'Benign')
#
#
# ('b066.tif', 'Benign')
#
#
# ('b067.tif', 'Benign')
#
#
# ('b068.tif', 'Benign')
#
#
# ('b069.tif', 'Benign')
#
#
# ('b070.tif', 'Benign')
#
#
# ('b071.tif', 'Benign')
#
#
# ('b072.tif', 'Benign')
#
#
# ('b073.tif', 'Benign')
#
#
# ('b074.tif', 'Benign')
#
#
# ('b075.tif', 'Benign')
#
#
# ('b076.tif', 'Benign')
#
#
# ('b077.tif', 'Benign')
#
#
# ('b078.tif', 'Benign')
#
#
# ('b079.tif', 'Benign')
#
#
# ('b080.tif', 'Benign')
#
#
# ('b081.tif', 'Benign')
#
#
# ('b082.tif', 'Benign')
#
#
# ('b083.tif', 'Benign')
#
#
# ('b084.tif', 'Benign')
#
#
# ('b085.tif', 'Benign')
#
#
# ('b086.tif', 'Benign')
#
#
# ('b087.tif', 'Benign')
#
#
# ('b088.tif', 'Benign')
#
#
# ('b089.tif', 'Benign')
#
#
# ('b090.tif', 'Benign')
#
#
# ('b091.tif', 'Benign')
#
#
# ('b092.tif', 'Benign')
#
#
# ('b093.tif', 'Benign')
#
#
# ('b094.tif', 'Benign')
#
#
# ('b095.tif', 'Benign')
#
#
# ('b096.tif', 'Benign')
#
#
# ('b097.tif', 'Benign')
#
#
# ('b098.tif', 'Benign')
#
#
# ('b099.tif', 'Benign')
#
#
# ('b100.tif', 'Benign')
#
#
# ('is001.tif', 'InSitu')
#
#
# ('is002.tif', 'InSitu')
#
#
# ('is003.tif', 'InSitu')
#
#
# ('is004.tif', 'InSitu')
#
#
# ('is005.tif', 'InSitu')
#
#
# ('is006.tif', 'InSitu')
#
#
# ('is007.tif', 'InSitu')
#
#
# ('is008.tif', 'InSitu')
#
#
# ('is009.tif', 'InSitu')
#
#
# ('is010.tif', 'InSitu')
#
#
# ('is011.tif', 'InSitu')
#
#
# ('is012.tif', 'InSitu')
#
#
# ('is013.tif', 'InSitu')
#
#
# ('is014.tif', 'InSitu')
#
#
# ('is015.tif', 'InSitu')
#
#
# ('is016.tif', 'InSitu')
#
#
# ('is017.tif', 'InSitu')
#
#
# ('is018.tif', 'InSitu')
#
#
# ('is019.tif', 'InSitu')
#
#
# ('is020.tif', 'InSitu')
#
#
# ('is021.tif', 'InSitu')
#
#
# ('is022.tif', 'InSitu')
#
#
# ('is023.tif', 'InSitu')
#
#
# ('is024.tif', 'InSitu')
#
#
# ('is025.tif', 'InSitu')
#
#
# ('is026.tif', 'InSitu')
#
#
# ('is027.tif', 'InSitu')
#
#
# ('is028.tif', 'InSitu')
#
#
# ('is029.tif', 'InSitu')
#
#
# ('is030.tif', 'InSitu')
#
#
# ('is031.tif', 'InSitu')
#
#
# ('is032.tif', 'InSitu')
#
#
# ('is033.tif', 'InSitu')
#
#
# ('is034.tif', 'InSitu')
#
#
# ('is035.tif', 'InSitu')
#
#
# ('is036.tif', 'InSitu')
#
#
# ('is037.tif', 'InSitu')
#
#
# ('is038.tif', 'InSitu')
#
#
# ('is039.tif', 'InSitu')
#
#
# ('is040.tif', 'InSitu')
#
#
# ('is041.tif', 'InSitu')
#
#
# ('is042.tif', 'InSitu')
#
#
# ('is043.tif', 'InSitu')
#
#
# ('is044.tif', 'InSitu')
#
#
# ('is045.tif', 'InSitu')
#
#
# ('is046.tif', 'InSitu')
#
#
# ('is047.tif', 'InSitu')
#
#
# ('is048.tif', 'InSitu')
#
#
# ('is049.tif', 'InSitu')
#
#
# ('is050.tif', 'InSitu')
#
#
# ('is051.tif', 'InSitu')
#
#
# ('is052.tif', 'InSitu')
#
#
# ('is053.tif', 'InSitu')
#
#
# ('is054.tif', 'InSitu')
#
#
# ('is055.tif', 'InSitu')
#
#
# ('is056.tif', 'InSitu')
#
#
# ('is057.tif', 'InSitu')
#
#
# ('is058.tif', 'InSitu')
#
#
# ('is059.tif', 'InSitu')
#
#
# ('is060.tif', 'InSitu')
#
#
# ('is061.tif', 'InSitu')
#
#
# ('is062.tif', 'InSitu')
#
#
# ('is063.tif', 'InSitu')
#
#
# ('is064.tif', 'InSitu')
#
#
# ('is065.tif', 'InSitu')
#
#
# ('is066.tif', 'InSitu')
#
#
# ('is067.tif', 'InSitu')
#
#
# ('is068.tif', 'InSitu')
#
#
# ('is069.tif', 'InSitu')
#
#
# ('is070.tif', 'InSitu')
#
#
# ('is071.tif', 'InSitu')
#
#
# ('is072.tif', 'InSitu')
#
#
# ('is073.tif', 'InSitu')
#
#
# ('is074.tif', 'InSitu')
#
#
# ('is075.tif', 'InSitu')
#
#
# ('is076.tif', 'InSitu')
#
#
# ('is077.tif', 'InSitu')
#
#
# ('is078.tif', 'InSitu')
#
#
# ('is079.tif', 'InSitu')
#
#
# ('is080.tif', 'InSitu')
#
#
# ('is081.tif', 'InSitu')
#
#
# ('is082.tif', 'InSitu')
#
#
# ('is083.tif', 'InSitu')
#
#
# ('is084.tif', 'InSitu')
#
#
# ('is085.tif', 'InSitu')
#
#
# ('is086.tif', 'InSitu')
#
#
# ('is087.tif', 'InSitu')
#
#
# ('is088.tif', 'InSitu')
#
#
# ('is089.tif', 'InSitu')
#
#
# ('is090.tif', 'InSitu')
#
#
# ('is091.tif', 'InSitu')
#
#
# ('is092.tif', 'InSitu')
#
#
# ('is093.tif', 'InSitu')
#
#
# ('is094.tif', 'InSitu')
#
#
# ('is095.tif', 'InSitu')
#
#
# ('is096.tif', 'InSitu')
#
#
# ('is097.tif', 'InSitu')
#
#
# ('is098.tif', 'InSitu')
#
#
# ('is099.tif', 'InSitu')
#
#
# ('is100.tif', 'InSitu')
#
#
# ('iv001.tif', 'Invasive')
#
#
# ('iv002.tif', 'Invasive')
#
#
# ('iv003.tif', 'Invasive')
#
#
# ('iv004.tif', 'Invasive')
#
#
# ('iv005.tif', 'Invasive')
#
#
# ('iv006.tif', 'Invasive')
#
#
# ('iv007.tif', 'Invasive')
#
#
# ('iv008.tif', 'Invasive')
#
#
# ('iv009.tif', 'Invasive')
#
#
# ('iv010.tif', 'Invasive')
#
#
# ('iv011.tif', 'Invasive')
#
#
# ('iv012.tif', 'Invasive')
#
#
# ('iv013.tif', 'Invasive')
#
#
# ('iv014.tif', 'Invasive')
#
#
# ('iv015.tif', 'Invasive')
#
#
# ('iv016.tif', 'Invasive')
#
#
# ('iv017.tif', 'Invasive')
#
#
# ('iv018.tif', 'Invasive')
#
#
# ('iv019.tif', 'Invasive')
#
#
# ('iv020.tif', 'Invasive')
#
#
# ('iv021.tif', 'Invasive')
#
#
# ('iv022.tif', 'Invasive')
#
#
# ('iv023.tif', 'Invasive')
#
#
# ('iv024.tif', 'Invasive')
#
#
# ('iv025.tif', 'Invasive')
#
#
# ('iv026.tif', 'Invasive')
#
#
# ('iv027.tif', 'Invasive')
#
#
# ('iv028.tif', 'Invasive')
#
#
# ('iv029.tif', 'Invasive')
#
#
# ('iv030.tif', 'Invasive')
#
#
# ('iv031.tif', 'Invasive')
#
#
# ('iv032.tif', 'Invasive')
#
#
# ('iv033.tif', 'Invasive')
#
#
# ('iv034.tif', 'Invasive')
#
#
# ('iv035.tif', 'Invasive')
#
#
# ('iv036.tif', 'Invasive')
#
#
# ('iv037.tif', 'Invasive')
#
#
# ('iv038.tif', 'Invasive')
#
#
# ('iv039.tif', 'Invasive')
#
#
# ('iv040.tif', 'Invasive')
#
#
# ('iv041.tif', 'Invasive')
#
#
# ('iv042.tif', 'Invasive')
#
#
# ('iv043.tif', 'Invasive')
#
#
# ('iv044.tif', 'Invasive')
#
#
# ('iv045.tif', 'Invasive')
#
#
# ('iv046.tif', 'Invasive')
#
#
# ('iv047.tif', 'Invasive')
#
#
# ('iv048.tif', 'Invasive')
#
#
# ('iv049.tif', 'Invasive')
#
#
# ('iv050.tif', 'Invasive')
#
#
# ('iv051.tif', 'Invasive')
#
#
# ('iv052.tif', 'Invasive')
#
#
# ('iv053.tif', 'Invasive')
#
#
# ('iv054.tif', 'Invasive')
#
#
# ('iv055.tif', 'Invasive')
#
#
# ('iv056.tif', 'Invasive')
#
#
# ('iv057.tif', 'Invasive')
#
#
# ('iv058.tif', 'Invasive')
#
#
# ('iv059.tif', 'Invasive')
#
#
# ('iv060.tif', 'Invasive')
#
#
# ('iv061.tif', 'Invasive')
#
#
# ('iv062.tif', 'Invasive')
#
#
# ('iv063.tif', 'Invasive')
#
#
# ('iv064.tif', 'Invasive')
#
#
# ('iv065.tif', 'Invasive')
#
#
# ('iv066.tif', 'Invasive')
#
#
# ('iv067.tif', 'Invasive')
#
#
# ('iv068.tif', 'Invasive')
#
#
# ('iv069.tif', 'Invasive')
#
#
# ('iv070.tif', 'Invasive')
#
#
# ('iv071.tif', 'Invasive')
#
#
# ('iv072.tif', 'Invasive')
#
#
# ('iv073.tif', 'Invasive')
#
#
# ('iv074.tif', 'Invasive')
#
#
# ('iv075.tif', 'Invasive')
#
#
# ('iv076.tif', 'Invasive')
#
#
# ('iv077.tif', 'Invasive')
#
#
# ('iv078.tif', 'Invasive')
#
#
# ('iv079.tif', 'Invasive')
#
#
# ('iv080.tif', 'Invasive')
#
#
# ('iv081.tif', 'Invasive')
#
#
# ('iv082.tif', 'Invasive')
#
#
# ('iv083.tif', 'Invasive')
#
#
# ('iv084.tif', 'Invasive')
#
#
# ('iv085.tif', 'Invasive')
#
#
# ('iv086.tif', 'Invasive')
#
#
# ('iv087.tif', 'Invasive')
#
#
# ('iv088.tif', 'Invasive')
#
#
# ('iv089.tif', 'Invasive')
#
#
# ('iv090.tif', 'Invasive')
#
#
# ('iv091.tif', 'Invasive')
#
#
# ('iv092.tif', 'Invasive')
#
#
# ('iv093.tif', 'Invasive')
#
#
# ('iv094.tif', 'Invasive')
#
#
# ('iv095.tif', 'Invasive')
#
#
# ('iv096.tif', 'Invasive')
#
#
# ('iv097.tif', 'Invasive')
#
#
# ('iv098.tif', 'Invasive')
#
#
# ('iv099.tif', 'Invasive')
#
#
# ('iv100.tif', 'Invasive')
#
#
# ('Thereis', 'nothing')

# %%
#una volta ottenute le due liste, voglio andare ad ordinarmi la lista valori reali

#confornto prima di tutto se le due liste contengono lo stesso numero di elementi
if len(y_pred) == len(y_vere):
    print("Le due liste hanno la stessa lunghezza.")
else:
    print("Le due liste hanno lunghezze diverse.")


#andiamo a debuggare -- - vabbe------------------:)---mandiamo avanti il codice RICORDA DI FIXAREEE
print("La lunghezza della lista PRED è:", len(y_pred))
print("La lunghezza della lista VERE è:", len(y_vere))



# Inizializzazione della lista di coppie ordinata
ORDINATA = []


#STACOSANONFUNZIONA
my_counter = 0
# Out:
# Le due liste hanno la stessa lunghezza.
# La lunghezza della lista PRED è: 400
# La lunghezza della lista VERE è: 400

# %%
# Converti le liste in set per poter fare l'operazione di differenza
set_b = set(y_vere)
set_a = set(y_pred)

# Trova le coppie che sono in B ma non in A
differenza = set_b - set_a

# Converti il risultato in una lista (se necessario)
differenza_lista = list(differenza)

# Stampa la differenza
print("Coppie presenti in B ma non in A:", differenza_lista)
# Out:
# Coppie presenti in B ma non in A: [('n061.tif', 'Normal'), ('is078.tif', 'InSitu'), ('iv068.tif', 'Invasive'), ('is022.tif', 'InSitu'), ('is024.tif', 'InSitu'), ('b025.tif', 'Benign'), ('iv077.tif', 'Invasive'), ('n007.tif', 'Normal'), ('b019.tif', 'Benign'), ('b024.tif', 'Benign'), ('n095.tif', 'Normal'), ('n013.tif', 'Normal'), ('iv098.tif', 'Invasive'), ('n088.tif', 'Normal'), ('is091.tif', 'InSitu'), ('is050.tif', 'InSitu'), ('n096.tif', 'Normal'), ('b083.tif', 'Benign'), ('n008.tif', 'Normal'), ('b068.tif', 'Benign'), ('b012.tif', 'Benign'), ('iv053.tif', 'Invasive'), ('n078.tif', 'Normal'), ('is093.tif', 'InSitu'), ('b007.tif', 'Benign'), ('b049.tif', 'Benign'), ('is042.tif', 'InSitu'), ('b053.tif', 'Benign'), ('n063.tif', 'Normal'), ('n032.tif', 'Normal'), ('b099.tif', 'Benign'), ('b046.tif', 'Benign'), ('n074.tif', 'Normal'), ('is053.tif', 'InSitu'), ('n098.tif', 'Normal'), ('n003.tif', 'Normal'), ('n028.tif', 'Normal'), ('n070.tif', 'Normal'), ('n085.tif', 'Normal'), ('iv002.tif', 'Invasive'), ('is034.tif', 'InSitu'), ('is072.tif', 'InSitu'), ('b058.tif', 'Benign'), ('b100.tif', 'Benign'), ('is040.tif', 'InSitu'), ('is074.tif', 'InSitu'), ('n093.tif', 'Normal'), ('b081.tif', 'Benign'), ('is054.tif', 'InSitu'), ('b059.tif', 'Benign'), ('n012.tif', 'Normal'), ('is011.tif', 'InSitu'), ('b087.tif', 'Benign'), ('iv084.tif', 'Invasive'), ('b076.tif', 'Benign'), ('b097.tif', 'Benign'), ('is057.tif', 'InSitu'), ('b047.tif', 'Benign'), ('is080.tif', 'InSitu'), ('n056.tif', 'Normal'), ('n030.tif', 'Normal'), ('is003.tif', 'InSitu'), ('n002.tif', 'Normal'), ('b042.tif', 'Benign'), ('n072.tif', 'Normal'), ('b050.tif', 'Benign'), ('b002.tif', 'Benign'), ('n060.tif', 'Normal'), ('iv004.tif', 'Invasive'), ('is089.tif', 'InSitu'), ('n048.tif', 'Normal'), ('b077.tif', 'Benign'), ('n068.tif', 'Normal'), ('is096.tif', 'InSitu'), ('iv074.tif', 'Invasive'), ('iv096.tif', 'Invasive'), ('b035.tif', 'Benign'), ('is033.tif', 'InSitu'), ('is081.tif', 'InSitu'), ('n027.tif', 'Normal'), ('b066.tif', 'Benign'), ('b069.tif', 'Benign'), ('iv061.tif', 'Invasive'), ('n037.tif', 'Normal'), ('b060.tif', 'Benign'), ('iv009.tif', 'Invasive'), ('n090.tif', 'Normal'), ('b003.tif', 'Benign'), ('n080.tif', 'Normal'), ('iv006.tif', 'Invasive'), ('n018.tif', 'Normal'), ('n017.tif', 'Normal'), ('n071.tif', 'Normal'), ('b067.tif', 'Benign'), ('b048.tif', 'Benign'), ('is043.tif', 'InSitu'), ('is064.tif', 'InSitu'), ('n069.tif', 'Normal'), ('n023.tif', 'Normal'), ('b079.tif', 'Benign'), ('b043.tif', 'Benign'), ('b032.tif', 'Benign'), ('is069.tif', 'InSitu'), ('n091.tif', 'Normal'), ('n009.tif', 'Normal'), ('n054.tif', 'Normal'), ('iv003.tif', 'Invasive'), ('is090.tif', 'InSitu'), ('n005.tif', 'Normal'), ('iv089.tif', 'Invasive'), ('n051.tif', 'Normal'), ('iv065.tif', 'Invasive'), ('is010.tif', 'InSitu'), ('b098.tif', 'Benign'), ('b086.tif', 'Benign'), ('is021.tif', 'InSitu'), ('n004.tif', 'Normal'), ('b018.tif', 'Benign'), ('iv007.tif', 'Invasive'), ('n065.tif', 'Normal'), ('is059.tif', 'InSitu'), ('is071.tif', 'InSitu'), ('iv062.tif', 'Invasive'), ('b038.tif', 'Benign'), ('n075.tif', 'Normal'), ('is019.tif', 'InSitu'), ('is013.tif', 'InSitu'), ('is015.tif', 'InSitu'), ('is087.tif', 'InSitu'), ('n047.tif', 'Normal'), ('b056.tif', 'Benign'), ('b001.tif', 'Benign'), ('b041.tif', 'Benign'), ('is006.tif', 'InSitu'), ('is002.tif', 'InSitu'), ('n046.tif', 'Normal'), ('is044.tif', 'InSitu'), ('is094.tif', 'InSitu'), ('is083.tif', 'InSitu'), ('n050.tif', 'Normal'), ('is099.tif', 'InSitu'), ('n058.tif', 'Normal'), ('is004.tif', 'InSitu'), ('b040.tif', 'Benign'), ('is001.tif', 'InSitu'), ('is049.tif', 'InSitu'), ('is056.tif', 'InSitu'), ('iv028.tif', 'Invasive'), ('n079.tif', 'Normal'), ('b089.tif', 'Benign'), ('n021.tif', 'Normal'), ('n092.tif', 'Normal'), ('is046.tif', 'InSitu'), ('b096.tif', 'Benign'), ('n006.tif', 'Normal'), ('n022.tif', 'Normal'), ('b064.tif', 'Benign'), ('n100.tif', 'Normal'), ('n016.tif', 'Normal'), ('iv010.tif', 'Invasive'), ('iv033.tif', 'Invasive' ...

# %%
for coppia in y_vere: #Il ciclo viene operato sulla stringa piu corta ed e`per questo che le due stringhe vengono di lunghezza uguale pur non essendolo.!!!!!!!-------------
    ticerco = coppia[0]  # Estrai il primo elemento della coppia corrente di A e salvalo in ticerco
    #print("\n", my_counter) #segnala l'avvenuta aggiunta di un elemento alla lista ordinata
    # Secondo ciclo for per cercare ticerco in tutti i primi elementi delle coppie presenti nella lista di coppie B
    for coppia_b in y_pred:
        # Se trovi ticerco in uno dei primi elementi delle coppie di B
        if ticerco == coppia_b[0]:
            # Aggiungi la coppia di B trovata nella lista ORDINATA
            ORDINATA.append(coppia_b)
            my_counter = my_counter + 1

print("LA LISTA PREDETTA ORDINATA e'", )

for coppia in ORDINATA:
    print(coppia)
    print("\n")
# Out:
# LA LISTA PREDETTA ORDINATA e'
# ('n001.tif', 'Invasive')
#
#
# ('n002.tif', 'Invasive')
#
#
# ('n003.tif', 'Invasive')
#
#
# ('n004.tif', 'Invasive')
#
#
# ('n005.tif', 'InSitu')
#
#
# ('n006.tif', 'Invasive')
#
#
# ('n007.tif', 'InSitu')
#
#
# ('n008.tif', 'Invasive')
#
#
# ('n009.tif', 'Invasive')
#
#
# ('n010.tif', 'Invasive')
#
#
# ('n011.tif', 'Invasive')
#
#
# ('n012.tif', 'Invasive')
#
#
# ('n013.tif', 'Invasive')
#
#
# ('n014.tif', 'Invasive')
#
#
# ('n015.tif', 'Invasive')
#
#
# ('n016.tif', 'Invasive')
#
#
# ('n017.tif', 'Invasive')
#
#
# ('n018.tif', 'Invasive')
#
#
# ('n019.tif', 'Invasive')
#
#
# ('n020.tif', 'Invasive')
#
#
# ('n021.tif', 'Invasive')
#
#
# ('n022.tif', 'Invasive')
#
#
# ('n023.tif', 'Invasive')
#
#
# ('n024.tif', 'Invasive')
#
#
# ('n025.tif', 'Invasive')
#
#
# ('n026.tif', 'Invasive')
#
#
# ('n027.tif', 'Invasive')
#
#
# ('n028.tif', 'Invasive')
#
#
# ('n029.tif', 'Invasive')
#
#
# ('n030.tif', 'Invasive')
#
#
# ('n031.tif', 'Invasive')
#
#
# ('n032.tif', 'Invasive')
#
#
# ('n033.tif', 'Invasive')
#
#
# ('n034.tif', 'Invasive')
#
#
# ('n035.tif', 'Invasive')
#
#
# ('n036.tif', 'Invasive')
#
#
# ('n037.tif', 'Invasive')
#
#
# ('n038.tif', 'InSitu')
#
#
# ('n039.tif', 'Invasive')
#
#
# ('n040.tif', 'Invasive')
#
#
# ('n041.tif', 'Invasive')
#
#
# ('n042.tif', 'Invasive')
#
#
# ('n043.tif', 'Invasive')
#
#
# ('n044.tif', 'Invasive')
#
#
# ('n045.tif', 'Invasive')
#
#
# ('n046.tif', 'Invasive')
#
#
# ('n047.tif', 'InSitu')
#
#
# ('n048.tif', 'Invasive')
#
#
# ('n049.tif', 'Normal')
#
#
# ('n050.tif', 'Invasive')
#
#
# ('n051.tif', 'Invasive')
#
#
# ('n052.tif', 'Invasive')
#
#
# ('n053.tif', 'Invasive')
#
#
# ('n054.tif', 'Benign')
#
#
# ('n055.tif', 'Invasive')
#
#
# ('n056.tif', 'Invasive')
#
#
# ('n057.tif', 'Invasive')
#
#
# ('n058.tif', 'Invasive')
#
#
# ('n059.tif', 'Invasive')
#
#
# ('n060.tif', 'InSitu')
#
#
# ('n061.tif', 'Invasive')
#
#
# ('n062.tif', 'Invasive')
#
#
# ('n063.tif', 'Invasive')
#
#
# ('n064.tif', 'Invasive')
#
#
# ('n065.tif', 'Invasive')
#
#
# ('n066.tif', 'Invasive')
#
#
# ('n067.tif', 'Invasive')
#
#
# ('n068.tif', 'Invasive')
#
#
# ('n069.tif', 'Invasive')
#
#
# ('n070.tif', 'Invasive')
#
#
# ('n071.tif', 'Invasive')
#
#
# ('n072.tif', 'Invasive')
#
#
# ('n073.tif', 'Invasive')
#
#
# ('n074.tif', 'Invasive')
#
#
# ('n075.tif', 'Invasive')
#
#
# ('n076.tif', 'Invasive')
#
#
# ('n077.tif', 'Invasive')
#
#
# ('n078.tif', 'Invasive')
#
#
# ('n079.tif', 'Invasive')
#
#
# ('n080.tif', 'Invasive')
#
#
# ('n081.tif', 'Invasive')
#
#
# ('n082.tif', 'InSitu')
#
#
# ('n083.tif', 'InSitu')
#
#
# ('n084.tif', 'Invasive')
#
#
# ('n085.tif', 'Invasive')
#
#
# ('n086.tif', 'Invasive')
#
#
# ('n087.tif', 'InSitu')
#
#
# ('n088.tif', 'InSitu')
#
#
# ('n089.tif', 'InSitu')
#
#
# ('n090.tif', 'InSitu')
#
#
# ('n091.tif', 'Invasive')
#
#
# ('n092.tif', 'Invasive')
#
#
# ('n093.tif', 'InSitu')
#
#
# ('n094.tif', 'Invasive')
#
#
# ('n095.tif', 'Invasive')
#
#
# ('n096.tif', 'Invasive')
#
#
# ('n097.tif', 'Invasive')
#
#
# ('n098.tif', 'Invasive')
#
#
# ('n099.tif', 'Invasive')
#
#
# ('n100.tif', 'Invasive')
#
#
# ('b001.tif', 'Invasive')
#
#
# ('b002.tif', 'Invasive')
#
#
# ('b003.tif', 'Invasive')
#
#
# ('b004.tif', 'Invasive')
#
#
# ('b005.tif', 'Invasive')
#
#
# ('b006.tif', 'Invasive')
#
#
# ('b007.tif', 'Invasive')
#
#
# ('b008.tif', 'Invasive')
#
#
# ('b009.tif', 'Invasive')
#
#
# ('b010.tif', 'Invasive')
#
#
# ('b011.tif', 'Benign')
#
#
# ('b012.tif', 'Invasive')
#
#
# ('b013.tif', 'Invasive')
#
#
# ('b014.tif', 'Invasive')
#
#
# ('b015.tif', 'Invasive')
#
#
# ('b016.tif', 'Invasive')
#
#
# ('b017.tif', 'Invasive')
#
#
# ('b018.tif', 'Invasive')
#
#
# ('b019.tif', 'Invasive')
#
#
# ('b020.tif', 'Invasive')
#
#
# ('b021.tif', 'Invasive')
#
#
# ('b022.tif', 'Invasive')
#
#
# ('b023.tif', 'Invasive')
#
#
# ('b024.tif', 'Invasive')
#
#
# ('b025.tif', 'Invasive')
#
#
# ('b026.tif', 'InSitu')
#
#
# ('b027.tif', 'Invasive')
#
#
# ('b028.tif', 'Invasive')
#
#
# ('b029.tif', 'Invasive')
#
#
# ('b030.tif', 'Invasive')
#
#
# ('b031.tif', 'Benign')
#
#
# ('b032.tif', 'Invasive')
#
#
# ('b033.tif', 'Benign')
#
#
# ('b034.tif', 'Invasive')
#
#
# ('b035.tif', 'Invasive')
#
#
# ('b036.tif', 'InSitu')
#
#
# ('b037.tif', 'Invasive')
#
#
# ('b038.tif', 'Invasive')
#
#
# ('b039.tif', 'Invasive')
#
#
# ('b040.tif', 'Invasive')
#
#
# ('b041.tif', 'Invasive')
#
#
# ('b042.tif', 'Invasive')
#
#
# ('b043.tif', 'Invasive')
#
#
# ('b044.tif', 'Invasive')
#
#
# ('b045.tif', 'Invasive')
#
#
# ('b046.tif', 'Invasive')
#
#
# ('b047.tif', 'Invasive')
#
#
# ('b048.tif', 'Invasive')
#
#
# ('b049.tif', 'Invasive')
#
#
# ('b050.tif', 'Invasive')
#
#
# ('b051.tif', 'Invasive')
#
#
# ('b052.tif', 'Invasive')
#
#
# ('b053.tif', 'Invasive')
#
#
# ('b054.tif', 'Benign')
#
#
# ('b055.tif', 'Invasive')
#
#
# ('b056.tif', 'Invasive')
#
#
# ('b057.tif', 'Invasive')
#
#
# ('b058.tif', 'Invasive')
#
#
# ('b059.tif', 'Invasive')
#
#
# ('b060.tif', 'Invasive')
#
#
# ('b061.tif', 'Invasive')
#
#
# ('b062.tif', 'Invasive')
#
#
# ('b063.tif', 'InSitu')
#
#
# ('b064.tif', 'Invasive')
#
#
# ('b065.tif', 'Invasive')
#
#
# ('b066.tif', 'Invasive')
#
#
# ('b067.tif', 'Invasive')
#
#
# ('b068.tif', 'Invasive')
#
#
# ('b069.tif', 'Invasive')
#
#
# ('b070.tif', 'Invasive')
#
#
# ('b071.tif', 'Invasive')
#
#
# ('b072.tif', 'Invasive')
#
#
# ('b073.tif', 'Invasive')
#
#
# ('b074.tif', 'Invasive')
#
#
# ('b075.tif', 'Invasive')
#
#
# ('b076.tif', 'Invasive')
#
#
# ('b077.tif', 'Invasive')
#
#
# ('b078.tif', 'Invasive')
#
#
# ('b079.tif', 'Invasive')
#
#
# ('b080.tif', 'Invasive')
#
#
# ('b081.tif', 'Invasive')
#
#
# ('b082.tif', 'Invasive')
#
#
# ('b083.tif', 'Invasive')
#
#
# ('b084.tif', 'Invasive')
#
#
# ('b085.tif', 'Invasive')
#
#
# ('b086.tif', 'InSitu')
#
#
# ('b087.tif', 'Invasive')
#
#
# ('b088.tif', 'Invasive')
#
#
# ('b089.tif', 'Invasive')
#
#
# ('b090.tif', 'Invasive')
#
#
# ('b091.tif', 'Invasive')
#
#
# ('b092.tif', 'Normal')
#
#
# ('b093.tif', 'Invasive')
#
#
# ('b094.tif', 'Invasive')
#
#
# ('b095.tif', 'Invasive')
#
#
# ('b096.tif', 'Invasive')
#
#
# ('b097.tif', 'Invasive')
#
#
# ('b098.tif', 'Invasive')
#
#
# ('b099.tif', 'Invasive')
#
#
# ('b100.tif', 'Invasive')
#
#
# ('is001.tif', 'Invasive')
#
#
# ('is002.tif', 'Invasive')
#
#
# ('is003.tif', 'Invasive')
#
#
# ('is004.tif', 'Invasive')
#
#
# ('is005.tif', 'Invasive')
#
#
# ('is006.tif', 'Invasive')
#
#
# ('is007.tif', 'Invasive')
#
#
# ('is008.tif', 'Invasive')
#
#
# ('is009.tif', 'Invasive')
#
#
# ('is010.tif', 'Invasive')
#
#
# ('is011.tif', 'Invasive')
#
#
# ('is012.tif', 'Invasive')
#
#
# ('is013.tif', 'Invasive')
#
#
# ('is014.tif', 'Invasive')
#
#
# ('is015.tif', 'Invasive')
#
#
# ('is016.tif', 'Invasive')
#
#
# ('is017.tif', 'Invasive')
#
#
# ('is018.tif', 'Invasive')
#
#
# ('is019.tif', 'Invasive')
#
#
# ('is020.tif', 'Invasive')
#
#
# ('is021.tif', 'Invasive')
#
#
# ('is022.tif', 'Invasive')
#
#
# ('is023.tif', 'Invasive')
#
#
# ('is024.tif', 'Invasive')
#
#
# ('is025.tif', 'Invasive')
#
#
# ('is026.tif', 'Invasive')
#
#
# ('is027.tif', 'Invasive')
#
#
# ('is028.tif', 'Invasive')
#
#
# ('is029.tif', 'Invasive')
#
#
# ('is030.tif', 'Invasive')
#
#
# ('is031.tif', 'Invasive')
#
#
# ('is032.tif', 'Invasive')
#
#
# ('is033.tif', 'Invasive')
#
#
# ('is034.tif', 'Invasive')
#
#
# ('is035.tif', 'Invasive')
#
#
# ('is036.tif', 'Invasive')
#
#
# ('is037.tif', 'Invasive')
#
#
# ('is038.tif', 'InSitu')
#
#
# ('is039.tif', 'InSitu')
#
#
# ('is040.tif', 'Invasive')
#
#
# ('is041.tif', 'Invasive')
#
#
# ('is042.tif', 'Invasive')
#
#
# ('is043.tif', 'Invasive')
#
#
# ('is044.tif', 'Invasive')
#
#
# ('is045.tif', 'Invasive')
#
#
# ('is046.tif', 'Invasive')
#
#
# ('is047.tif', 'Invasive')
#
#
# ('is048.tif', 'Invasive')
#
#
# ('is049.tif', 'Invasive')
#
#
# ('is050.tif', 'Invasive')
#
#
# ('is051.tif', 'Invasive')
#
#
# ('is052.tif', 'Invasive')
#
#
# ('is053.tif', 'Invasive')
#
#
# ('is054.tif', 'Invasive')
#
#
# ('is055.tif', 'Invasive')
#
#
# ('is056.tif', 'Invasive')
#
#
# ('is057.tif', 'Invasive')
#
#
# ('is058.tif', 'Invasive')
#
#
# ('is059.tif', 'Invasive')
#
#
# ('is060.tif', 'Invasive')
#
#
# ('is061.tif', 'InSitu')
#
#
# ('is062.tif', 'InSitu')
#
#
# ('is063.tif', 'Invasive')
#
#
# ('is064.tif', 'Invasive')
#
#
# ('is065.tif', 'Invasive')
#
#
# ('is066.tif', 'Invasive')
#
#
# ('is067.tif', 'Invasive')
#
#
# ('is068.tif', 'Invasive')
#
#
# ('is069.tif', 'Invasive')
#
#
# ('is070.tif', 'Invasive')
#
#
# ('is071.tif', 'Invasive')
#
#
# ('is072.tif', 'Invasive')
#
#
# ('is073.tif', 'Invasive')
#
#
# ('is074.tif', 'Invasive')
#
#
# ('is075.tif', 'InSitu')
#
#
# ('is076.tif', 'InSitu')
#
#
# ('is077.tif', 'Invasive')
#
#
# ('is078.tif', 'Invasive')
#
#
# ('is079.tif', 'Invasive')
#
#
# ('is080.tif', 'Invasive')
#
#
# ('is081.tif', 'Invasive')
#
#
# ('is082.tif', 'Invasive')
#
#
# ('is083.tif', 'Invasive')
#
#
# ('is084.tif', 'Invasive')
#
#
# ('is085.tif', 'Invasive')
#
#
# ('is086.tif', 'Invasive')
#
#
# ('is087.tif', 'Invasive')
#
#
# ('is088.tif', 'Invasive')
#
#
# ('is089.tif', 'Invasive')
#
#
# ('is090.tif', 'Invasive')
#
#
# ('is091.tif', 'Invasive')
#
#
# ('is092.tif', 'Invasive')
#
#
# ('is093.tif', 'Invasive')
#
#
# ('is094.tif', 'Invasive')
#
#
# ('is095.tif', 'Invasive')
#
#
# ('is096.tif', 'Invasive')
#
#
# ('is097.tif', 'InSitu')
#
#
# ('is098.tif', 'Invasive')
#
#
# ('is099.tif', 'Invasive')
#
#
# ('is100.tif', 'InSitu')
#
#
# ('iv001.tif', 'Invasive')
#
#
# ('iv002.tif', 'InSitu')
#
#
# ('iv003.tif', 'InSitu')
#
#
# ('iv004.tif', 'InSitu')
#
#
# ('iv005.tif', 'InSitu')
#
#
# ('iv006.tif', 'InSitu')
#
#
# ('iv007.tif', 'InSitu')
#
#
# ('iv008.tif', 'InSitu')
#
#
# ('iv009.tif', 'InSitu')
#
#
# ('iv010.tif', 'InSitu')
#
#
# ('iv011.tif', 'InSitu')
#
#
# ('iv012.tif', 'Invasive')
#
#
# ('iv013.tif', 'Invasive')
#
#
# ('iv014.tif', 'Invasive')
#
#
# ('iv015.tif', 'Invasive')
#
#
# ('iv016.tif', 'Invasive')
#
#
# ('iv017.tif', 'Invasive')
#
#
# ('iv018.tif', 'Invasive')
#
#
# ('iv019.tif', 'Invasive')
#
#
# ('iv020.tif', 'Invasive')
#
#
# ('iv021.tif', 'Invasive')
#
#
# ('iv022.tif', 'Invasive')
#
#
# ('iv023.tif', 'Invasive')
#
#
# ('iv024.tif', 'Invasive')
#
#
# ('iv025.tif', 'Invasive')
#
#
# ('iv026.tif', 'Invasive')
#
#
# ('iv027.tif', 'Invasive')
#
#
# ('iv028.tif', 'InSitu')
#
#
# ('iv029.tif', 'Invasive')
#
#
# ('iv030.tif', 'Invasive')
#
#
# ('iv031.tif', 'Invasive')
#
#
# ('iv032.tif', 'InSitu')
#
#
# ('iv033.tif', 'InSitu')
#
#
# ('iv034.tif', 'Invasive')
#
#
# ('iv035.tif', 'Invasive')
#
#
# ('iv036.tif', 'Invasive')
#
#
# ('iv037.tif', 'Invasive')
#
#
# ('iv038.tif', 'InSitu')
#
#
# ('iv039.tif', 'InSitu')
#
#
# ('iv040.tif', 'InSitu')
#
#
# ('iv041.tif', 'Invasive')
#
#
# ('iv042.tif', 'Invasive')
#
#
# ('iv043.tif', 'Invasive')
#
#
# ('iv044.tif', 'Invasive')
#
#
# ('iv045.tif', 'Invasive')
#
#
# ('iv046.tif', 'Invasive')
#
#
# ('iv047.tif', 'Invasive')
#
#
# ('iv048.tif', 'Invasive')
#
#
# ('iv049.tif', 'Invasive')
#
#
# ('iv050.tif', 'Invasive')
#
#
# ('iv051.tif', 'Invasive')
#
#
# ('iv052.tif', 'Invasive')
#
#
# ('iv053.tif', 'InSitu')
#
#
# ('iv054.tif', 'Invasive')
#
#
# ('iv055.tif', 'InSitu')
#
#
# ('iv056.tif', 'Invasive')
#
#
# ('iv057.tif', 'Invasive')
#
#
# ('iv058.tif', 'Invasive')
#
#
# ('iv059.tif', 'Invasive')
#
#
# ('iv060.tif', 'InSitu')
#
#
# ('iv061.tif', 'InSitu')
#
#
# ('iv062.tif', 'InSitu')
#
#
# ('iv063.tif', 'Invasive')
#
#
# ('iv064.tif', 'Invasive')
#
#
# ('iv065.tif', 'InSitu')
#
#
# ('iv066.tif', 'Invasive')
#
#
# ('iv067.tif', 'Invasive')
#
#
# ('iv068.tif', 'InSitu')
#
#
# ('iv069.tif', 'InSitu')
#
#
# ('iv070.tif', 'InSitu')
#
#
# ('iv071.tif', 'Invasive')
#
#
# ('iv072.tif', 'Invasive')
#
#
# ('iv073.tif', 'Invasive')
#
#
# ('iv074.tif', 'InSitu')
#
#
# ('iv075.tif', 'InSitu')
#
#
# ('iv076.tif', 'Invasive')
#
#
# ('iv077.tif', 'InSitu')
#
#
# ('iv078.tif', 'Invasive')
#
#
# ('iv079.tif', 'Invasive')
#
#
# ('iv080.tif', 'Invasive')
#
#
# ('iv081.tif', 'InSitu')
#
#
# ('iv082.tif', 'Invasive')
#
#
# ('iv083.tif', 'Invasive')
#
#
# ('iv084.tif', 'InSitu')
#
#
# ('iv085.tif', 'InSitu')
#
#
# ('iv086.tif', 'InSitu')
#
#
# ('iv087.tif', 'Invasive')
#
#
# ('iv088.tif', 'Invasive')
#
#
# ('iv089.tif', 'InSitu')
#
#
# ('iv090.tif', 'Invasive')
#
#
# ('iv091.tif', 'Invasive')
#
#
# ('iv092.tif', 'Invasive')
#
#
# ('iv093.tif', 'Invasive')
#
#
# ('iv094.tif', 'Invasive')
#
#
# ('iv095.tif', 'Invasive')
#
#
# ('iv096.tif', 'InSitu')
#
#
# ('iv097.tif', 'InSitu')
#
#
# ('iv098.tif', 'InSitu')
#
#
# ('iv099.tif', 'InSitu')
#
#
# ('iv100.tif', 'Invasive')

# %%
#Quale è l'elemento che non ha un simile?

print("La lunghezza della lista PRED è:", len(ORDINATA)) #399
print("La lunghezza della lista VERE è:", len(y_vere)) #400
#stampa le lunghezze delle due stringhe per
i = 0
index = 0

# fai un for della lunghezza della lista piu lunga, in questo caso predicted labels

for coppia in ORDINATA:
    # Estrai il primo elemento dalla coppia corrente in l1
    elemento_l1 = coppia[0]
    i = index
    for pippo in y_vere:
        # Estrai il primo elemento dalla prima coppia in l2
        elemento_l2 = pippo[0] #perchè pippoi mi da solo lettere????????!
        #print(elemento_l2) #-------------------------------------------
        # Confronta i primi elementi
        if elemento_l1 == elemento_l2:
            print("Match")
            index = index+1
    if(i == index): #singifica che non è avvenuto l'aggiornamento
      print("Nessuna corrispondenza per: \n", elemento_l1)
# Out:
# La lunghezza della lista PRED è: 400
# La lunghezza della lista VERE è: 400
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match
# Match

# %%
#Per sicurezza stampati la lista A e B in un file di testo per compararle agevolmente
# Definizione della lista di coppie


# Nome del file di output
nome_file_p = '/content/drive/MyDrive/WE/lista_coppie_pred.txt'
nome_file_v = '/content/drive/MyDrive/WE/lista_coppie_vere.txt'

def scrivi_lista_in_file(lista_coppie, nome_file):
    try:
        with open(nome_file, 'w') as file:
            for coppia in lista_coppie:
                file.write(f"{coppia[0]}, {coppia[1]}\n")
        print(f"Lista di coppie scritta in {nome_file}")
    except Exception as e:
        print(f"Errore durante la scrittura nel file: {e}")

scrivi_lista_in_file(ORDINATA, nome_file_p)

scrivi_lista_in_file(y_vere, nome_file_v)
# Out:
# Lista di coppie scritta in /content/drive/MyDrive/WE/lista_coppie_pred.txt
# Lista di coppie scritta in /content/drive/MyDrive/WE/lista_coppie_vere.txt

# %%
#Ora posso estrarre le labels della prima e della seconda e calcolare l'accuracy

#estraggo le labels reali
reallabels = []
predictedlabels = []

# Iterazione sulla lista di coppie
for coppia in y_vere:
    # Aggiungi il secondo elemento della coppia alla lista reallabels
    reallabels.append(coppia[1])

# Stampare la lista reallabels
print(reallabels)

#estraggo le labels predette----------------------------------------------------------
# Iterazione sulla lista di coppie
for coppia in ORDINATA:
    # Aggiungi il secondo elemento della coppia alla lista reallabels
    predictedlabels.append(coppia[1])

# Stampare la lista reallabels
print(predictedlabels)
# Out:
# ['Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'In ...
# ['Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'Normal', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Benign', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Benign', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Benign', 'Invasive', 'Benign', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Benign', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Normal', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'InSitu', 'Invasive', 'Invasive', 'Invasive', 'Invasive', 'InSitu', 'InSitu', 'InSitu', 'Invasive', ' ...

# %%
len(reallabels), len(predictedlabels)
# Out:
# (400, 400)

# %%
from sklearn.metrics import accuracy_score

#look at the parameters and their meaning
accuracy_score(reallabels, predictedlabels)
# Out:
# 0.19
